# %% [markdown]
# # LSTM
#
# Implementação da previsão do consumo de cimento nos estados  do Brasil utilizando redes neurais LSTM
#
# > Dados utilizados disponíveis em: `https://github.com/LeiteJu/TCC/blob/main/dados/input/df.csv`
#
# Modelo:
# - Treinamento: dados de 01/2003 até 06/2017
# - Teste: dados de 07/2017 até 12/2019
#
# Experimentos:
# - camadas: 1,2,3,4
# - standard scaler, minmax scaler, power transformer, batch normalization
# - função de ativação relu e swish
# - epochs: 100, 200, 300, 400
#
#
# Melhores resultados:
#
#
# |      | LSTM |
# |------|------------------|
# | RMSE | 35316.32         |
# | MAE  | 21944.25         |
# | MAPE | 0.23             |

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import random
from scipy.stats import pearsonr
from collections import Counter

from tensorflow import keras
from tensorflow.keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.random import set_seed

sns.set_palette("Paired")

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler, PowerTransformer
from sklearn.preprocessing import SplineTransformer

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import r2_score

from sklearn.pipeline import Pipeline

import warnings
warnings.filterwarnings("ignore")

from keras.layers import BatchNormalization

# %% [markdown]
# # Constantes e funções

# %%
PATH="https://raw.githubusercontent.com/LeiteJu/TCC/main/dados/input/"

SIGLAS = ['AC', 'AL', 'AM', 'AP', 'BA', 'CE',
  'DF', 'ES', 'GO', 'MA',
  'MG', 'MS', 'MT', 'PA', 'PB',
  'PE', 'PI', 'PR', 'RJ',
  'RN', 'RO', 'RR', 'RS',
  'SC', 'SE', 'SP', 'TO']

LABELS=["subestima: -90%", "subestima entre -90% e 60%", "subestima entre -60% e -30%",
        "subestima entre -30% e 10%", "entre -10% e 10%", "superestima entre 10% e 30%", 
        "superestima entre 30% e 60%", "superestima entre 60% e 90%", "superestima mais de 90%"]

N='NORTE'
NE="NORDESTE"
CO='CENTRO OESTE'
SE='SUDESTE'
S = 'SUL'

REGIOES = {
    'AC': N, 'AL': NE, 'AM' : N, 'AP' : N, 'BA' : NE, 'CE' : NE,
    'DF' : CO, 'ES' : SE, 'GO' : CO, 'MA' : NE,
    'MG' : SE, 'MS' : CO, 'MT' : CO, 'PA' : N, 'PB' : NE,
    'PE' : NE, 'PI' : NE, 'PR' : S, 'RJ' : SE,
    'RN' : NE, 'RO' : N, 'RR' : N, 'RS' : S,
    'SC' : S, 'SE' : NE, 'SP' : SE, 'TO' : N}

# %%
# calcula metricas de regressao
def score_regression_metrics(y_test, y_test_pred):

    RMSE = mean_squared_error(y_true=y_test, y_pred=y_test_pred, squared=False)
    MAE = mean_absolute_error(y_true=y_test, y_pred=y_test_pred)
    MAPE = mean_absolute_percentage_error(y_true=y_test, y_pred=y_test_pred)

    scores = {
        "rmse": RMSE,
        "mae": MAE,
        "mape": MAPE,
    }

    return scores

# mostra as metricas de regressao 
def show_scores (scores):

    print ("Scores obtidos:")

    print (f"RMSE: {scores['rmse']}")
    print (f"MAE: {scores['mae']}")
    print (f"MAPE: {scores['mape']}")

# %%
# classifica o input de acordo com a categoria 
def categorize(x):
    if x < - 0.9:
        return LABELS[0]
    elif x < - 0.6:
        return LABELS[1]
    elif x < - 0.3:
        return LABELS[2]
    elif x < - 0.1:
        return LABELS[3]
    elif x < 0.1:
        return LABELS[4]
    elif x < 0.3:
        return LABELS[5]
    elif x < 0.6:
        return LABELS[6]
    elif x < 0.9:
        return LABELS[7]
    else:
        return LABELS[8]

# %%
# mostra os deltas percentuais 
def show_delta (y_test, y_pred):
    
    data=(y_pred - y_test)/y_test

    error = pd.DataFrame(data, columns=['erro'])
    error['categoria']=error['erro'].apply(categorize)
    
    plt.figure(figsize=(28,6))
    
    plt.title("Distribuição do erro")
    plt.xlabel("Categorias")
    plt.ylabel("quantidade")

    g = sns.countplot(data=error, x='categoria', order=LABELS)
    g.set(ylabel="quantidade")
    total = error.shape[0]
    
    for p in g.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width()
        y = p.get_height()
        g.annotate(percentage, (x-0.4, y+1),ha='left')
    
    plt.show()
    
    return error

# %%
def get_regiao (x):
    return REGIOES[x]

# separa y_test e y_pred em dados por estado e ao longo do tempo
def get_pred (y_test, y_pred):
    
    # os testes sao realizados com dados de 07/2017 ate 12/2019
    init = pd.to_datetime("072017", format='%m%Y')
    end = pd.to_datetime("122019", format='%m%Y')
    data = pd.date_range(start=init, end=end, freq='MS').date
    
    # todas as datas se repetem para cada estado
    pred = pd.DataFrame(list(data) * 27, columns=['data']).sort_values('data')
    
    # todos os estados se repetem para cada data
    pred['estados'] = SIGLAS * 30
    
    # garante que todos os estados estao presentes em todas as datas 
    pred['y_test'] =  y_test[len(y_test) % 27 :].values
    pred['y_pred'] = y_pred[len(y_pred) % 27 :]
    
    pred = pred.set_index('data')
    
    pred['regiao'] = pred['estados'].apply(get_regiao)
    
    return pred

# %%
def show_pred (pred, states=SIGLAS):
    
    for state in states:
        
        fig, ax = plt.subplots()

        pred[pred['estados'] == state].plot(y="y_pred", ax=ax, figsize=(12,6), color="coral", title=f"Previsão x Dado Real: {state}", ylabel="Consumo")
        pred[pred['estados'] == state].plot(y="y_test", linestyle=' ', marker="o", ax=ax)

    plt.show()

# %%
# n_steps -> timestep no tempo .. pegar contexto
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the dataset
        if end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1, -1]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
class Scaler3DShape:
    
    def __init__(self, scaler=StandardScaler):
        self.scaler = scaler() 

    def fit_transform(self, x):
        x_new = self.scaler.fit_transform(x.reshape(-1, x.shape[-1])).reshape(x.shape)
        return x_new

    def transform(self, x):
        x_new = self.scaler.transform(x.reshape(-1, x.shape[-1])).reshape(x.shape)
        return x_new

# %%
def get_regiao (x):
    return REGIOES[x]

def get_pred (y_test, y_pred):
    
    init = pd.to_datetime("072017", format='%m%Y')
    end = pd.to_datetime("122019", format='%m%Y')
    data = pd.date_range(start=init, end=end, freq='MS').date
    
    pred = pd.DataFrame(list(data) * 27, columns=['data']).sort_values('data')
    
    pred['estados'] = SIGLAS * 30
    
    pred['y_test'] =  y_test[len(y_test) % 27 :].values
    pred['y_pred'] = y_pred[len(y_pred) % 27 :]
    
    pred = pred.set_index('data')
    
    pred['regiao'] = pred['estados'].apply(get_regiao)
    
    return pred

# %%
SEED = 41

def set_seeds (SEED=41):
    os.environ['PYTHONHASHSEED'] = str(SEED)
    set_seed(SEED)
    np.random.seed(SEED)
    random.seed(SEED)

# %%
set_seeds(SEED)

# %%
STATES = ['SP', 'RS','AL','DF']

# %% [markdown]
# # Dados

# %%
def load_data():
    
    df = pd.read_csv(f"{PATH}df.csv")
    
    x  = df.copy()
    x = x.sort_values(["data", "estados"])
    x = x.drop(["consumo", 'data'], axis=1)

    y = df.copy().sort_values(["data", "estados"])[['estados', 'data', 'consumo']]
    
    # processo de one-hot
    x = pd.get_dummies(data=x, columns=["estados"], drop_first=True)

    y = y['consumo']
    
    return x,y

# %% [markdown]
# # Experimentos

# %%
resultado = pd.DataFrame(columns=["lstm", "dense", "epochs", "neuronios", "ativacao_lstm", "ativacao_normal","normalizacao", "mae", "rmse", "mape"])

# %%
EPOCHS=[100, 200, 300]
CAMADAS=[1,2,3,4]
NEURONIOS=[256,128,64,32]
FUNCTION=["relu", "swish"]
FUNCTION_LSTM=["tanh", "relu", "swish"]
SCALER = [StandardScaler, MinMaxScaler, PowerTransformer]
TIMESTEPS = [3,5,7]

# %% [markdown]
# ## 1 camada

# %%
for epoch in EPOCHS:
    print (f"Epoch: {epoch}")
    for neuron in NEURONIOS:
        print (f"neuronios: {neuron}")
        for f in FUNCTION_LSTM:
            for s in SCALER:
                for t in TIMESTEPS:
                
                    set_seeds(41)

                    x,y = load_data()

                    timestep=t

                    df = x.copy()
                    df["consumo"] = y

                    df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

                    x_train, y_train = split_sequences(df_train.values, timestep)
                    x_test, y_test = split_sequences(df_test.values, timestep)


                    scaler = Scaler3DShape(s)
                    x_train = scaler.fit_transform(x_train)
                    x_test = scaler.transform(x_test)

                    model = Sequential()
                    model.add(LSTM(units=neuron, activation=f)),
                    model.add(Dropout(rate=0.10))
                    model.add(Dense(units=1))
                    model.compile(
                        optimizer=keras.optimizers.Adam(learning_rate=0.001),
                        loss="mse",
                        metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


                    history = model.fit(x_train, y_train, epochs=epoch, batch_size=32, verbose=0) 

                    y_pred = model.predict(x_test)
                    scores = score_regression_metrics(y_test, y_pred)
                    res = [1, 0, epoch, neuron, f, np.nan, s, scores['mae'], scores['rmse'], scores['mape']]
                    resultado = resultado.append(dict(zip(resultado.columns, res)), ignore_index=True)
# Out:
# Epoch: 100
# neuronios: 256
# ...
# 26/26 [==============================] - 0s 9ms/step
# neuronios: 128
# ...
# 26/26 [==============================] - 1s 10ms/step
# neuronios: 64
# ...
# 26/26 [==============================] - 0s 6ms/step
# neuronios: 32
# ...
# 26/26 [==============================] - 0s 4ms/step
# Epoch: 200
# neuronios: 256
# ...
# 26/26 [==============================] - 0s 10ms/step
# neuronios: 128
# ...
# 26/26 [==============================] - 1s 10ms/step
# neuronios: 64
# ...
# 26/26 [==============================] - 0s 4ms/step
# neuronios: 32
# ...
# 26/26 [==============================] - 0s 4ms/step
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
#       7 for t in TIMESTEPS:
#       9     set_seeds(41)
# ---> 11     x,y = load_data()
#      13     timestep=t
#      15     df = x.copy()
#
# Input In [12], in load_data()
#       1 def load_data():
# ...

# %%
resultado.style

# %%
resultado.to_csv("1_camada_lstm.csv", index=False)

# %% [markdown]
# ### 2 camadas

# %%
import itertools 
for epoch in EPOCHS:
    print (f"Epoch: {epoch}")
    for neuronios in itertools.combinations(NEURONIOS, 2):
        print (f"neuronios: {neuronios}")
        for f in FUNCTION_LSTM:
            for s in SCALER:
                for t in TIMESTEPS:
                
                    set_seeds(41)

                    x,y = load_data()

                    timestep=t

                    df = x.copy()
                    df["consumo"] = y

                    df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

                    x_train, y_train = split_sequences(df_train.values, timestep)
                    x_test, y_test = split_sequences(df_test.values, timestep)


                    scaler = Scaler3DShape(s)
                    x_train = scaler.fit_transform(x_train)
                    x_test = scaler.transform(x_test)

                    model = Sequential()
                    model.add(LSTM(units=neuronios[0], return_sequences=True, activation=f)),
                    model.add(LSTM(units=neuronios[1], activation=f)),
                    model.add(Dropout(rate=0.10))
                    model.add(Dense(units=1))
                    model.compile(
                        optimizer=keras.optimizers.Adam(learning_rate=0.001),
                        loss="mse",
                        metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


                    history = model.fit(x_train, y_train, epochs=epoch, batch_size=32, verbose=0) 

                    y_pred = model.predict(x_test)
                    scores = score_regression_metrics(y_test, y_pred)
                    res = [2, 0, epoch, neuronios, f, np.nan, s, scores['mae'], scores['rmse'], scores['mape']]
                    resultado = resultado.append(dict(zip(resultado.columns, res)), ignore_index=True)

# %%
resultado.to_csv("2_camada_lstm_dense.csv", index=False)
resultado.style

# %%
import itertools 
for epoch in EPOCHS:
    print (f"Epoch: {epoch}")
    for neuronios in itertools.combinations(NEURONIOS, 2):
        print (f"neuronios: {neuronios}")
        for f_lstm in FUNCTION_LSTM:
            for f_dense in FUNCTION:
                for s in SCALER:
                    for t in TIMESTEPS:

                        set_seeds(41)

                        x,y = load_data()

                        timestep=t

                        df = x.copy()
                        df["consumo"] = y

                        df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

                        x_train, y_train = split_sequences(df_train.values, timestep)
                        x_test, y_test = split_sequences(df_test.values, timestep)


                        scaler = Scaler3DShape(s)
                        x_train = scaler.fit_transform(x_train)
                        x_test = scaler.transform(x_test)

                        model = Sequential()
                        model.add(LSTM(units=neuronios[0], activation=f_lstm)),
                        model.add(Dense(units=neuronios[1], activation=f_dense)),
                        model.add(Dropout(rate=0.10))
                        model.add(Dense(units=1))
                        model.compile(
                            optimizer=keras.optimizers.Adam(learning_rate=0.001),
                            loss="mse",
                            metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


                        history = model.fit(x_train, y_train, epochs=epoch, batch_size=32, verbose=0) 

                        y_pred = model.predict(x_test)
                        scores = score_regression_metrics(y_test, y_pred)
                        res = [1, 1, epoch, neuronios, f_lstm, f_dense, s, scores['mae'], scores['rmse'], scores['mape']]
                        resultado = resultado.append(dict(zip(resultado.columns, res)), ignore_index=True)

# %%
resultado.to_csv("2_camada_lstm_dense1.csv", index=False)
resultado.style

# %% [markdown]
# ### 3 camadas

# %%
import itertools 
for epoch in EPOCHS:
    print (f"Epoch: {epoch}")
    for neuronios in itertools.combinations(NEURONIOS, 3):
        print (f"neuronios: {neuronios}")
        for f in FUNCTION_LSTM:
            for s in SCALER:
                for t in TIMESTEPS:
                
                    set_seeds(41)

                    x,y = load_data()

                    timestep=t

                    df = x.copy()
                    df["consumo"] = y

                    df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

                    x_train, y_train = split_sequences(df_train.values, timestep)
                    x_test, y_test = split_sequences(df_test.values, timestep)


                    scaler = Scaler3DShape(s)
                    x_train = scaler.fit_transform(x_train)
                    x_test = scaler.transform(x_test)

                    model = Sequential()
                    model.add(LSTM(units=neuronios[0], return_sequences=True, activation=f)),
                    model.add(LSTM(units=neuronios[1], return_sequences=True, activation=f)),
                    model.add(LSTM(units=neuronios[2], activation=f)),
                    model.add(Dropout(rate=0.10))
                    model.add(Dense(units=1))
                    model.compile(
                        optimizer=keras.optimizers.Adam(learning_rate=0.001),
                        loss="mse",
                        metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


                    history = model.fit(x_train, y_train, epochs=epoch, batch_size=32, verbose=0) 

                    y_pred = model.predict(x_test)
                    scores = score_regression_metrics(y_test, y_pred)
                    res = [3, 0, epoch, neuronios, f, np.nan, s, scores['mae'], scores['rmse'], scores['mape']]
                    resultado = resultado.append(dict(zip(resultado.columns, res)), ignore_index=True)

# %%
resultado.to_csv("3_camada_lstm.csv", index=False)
resultado.style

# %%
import itertools 
for epoch in EPOCHS:
    print (f"Epoch: {epoch}")
    for neuronios in itertools.combinations(NEURONIOS, 3):
        print (f"neuronios: {neuronios}")
        for f_lstm in FUNCTION_LSTM:
            for f_dense in FUNCTION:
                for s in SCALER:
                    for t in TIMESTEPS:

                        set_seeds(41)

                        x,y = load_data()

                        timestep=t

                        df = x.copy()
                        df["consumo"] = y

                        df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

                        x_train, y_train = split_sequences(df_train.values, timestep)
                        x_test, y_test = split_sequences(df_test.values, timestep)


                        scaler = Scaler3DShape(s)
                        x_train = scaler.fit_transform(x_train)
                        x_test = scaler.transform(x_test)

                        model = Sequential()
                        model.add(LSTM(units=neuronios[0], return_sequences=True, activation=f_lstm)),
                        model.add(LSTM(units=neuronios[1], activation=f_lstm)),
                        model.add(Dense(units=neuronios[2], activation=f_dense)),
                        model.add(Dropout(rate=0.10))
                        model.add(Dense(units=1))
                        model.compile(
                            optimizer=keras.optimizers.Adam(learning_rate=0.001),
                            loss="mse",
                            metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


                        history = model.fit(x_train, y_train, epochs=epoch, batch_size=32, verbose=0) 

                        y_pred = model.predict(x_test)
                        scores = score_regression_metrics(y_test, y_pred)
                        res = [2, 1, epoch, neuronios, f_lstm, f_dense, s, scores['mae'], scores['rmse'], scores['mape']]
                        resultado = resultado.append(dict(zip(resultado.columns, res)), ignore_index=True)

# %%
resultado.to_csv("3_camada_lstm_dense1.csv", index=False)
resultado.style

# %%
import itertools 
for epoch in EPOCHS:
    print (f"Epoch: {epoch}")
    for neuronios in itertools.combinations(NEURONIOS, 3):
        print (f"neuronios: {neuronios}")
        for f_lstm in FUNCTION_LSTM:
            for f_dense in FUNCTION:
                for s in SCALER:
                    for t in TIMESTEPS:

                        set_seeds(41)

                        x,y = load_data()

                        timestep=t

                        df = x.copy()
                        df["consumo"] = y

                        df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

                        x_train, y_train = split_sequences(df_train.values, timestep)
                        x_test, y_test = split_sequences(df_test.values, timestep)


                        scaler = Scaler3DShape(s)
                        x_train = scaler.fit_transform(x_train)
                        x_test = scaler.transform(x_test)

                        model = Sequential()
                        model.add(LSTM(units=neuronios[0], activation=f_lstm)),
                        model.add(Dense(units=neuronios[1], activation=f_dense)),
                        model.add(Dense(units=neuronios[2], activation=f_dense)),
                        model.add(Dropout(rate=0.10))
                        model.add(Dense(units=1))
                        model.compile(
                            optimizer=keras.optimizers.Adam(learning_rate=0.001),
                            loss="mse",
                            metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


                        history = model.fit(x_train, y_train, epochs=epoch, batch_size=32, verbose=0) 

                        y_pred = model.predict(x_test)
                        scores = score_regression_metrics(y_test, y_pred)
                        res = [1, 2, epoch, neuronios, f_lstm, f_dense, s, scores['mae'], scores['rmse'], scores['mape']]
                        resultado = resultado.append(dict(zip(resultado.columns, res)), ignore_index=True)

# %%
resultado.to_csv("3_camada_lstm_dense2.csv", index=False)
resultado.style

# %% [markdown]
# ## 1 camada LSTM (128)

# %% [markdown]
# #### sem relu e 100 epochs
#
# Scores obtidos:
# - RMSE: 230706.29448246318
# - MAE: 145620.90196747752
# - MAPE: 0.956438283696698

# %%
set_seeds(41)

x,y = load_data()

timestep=3

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=32)),
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 1s 3ms/step
# Scores obtidos:
# RMSE: 266811.8104189761
# MAE: 159247.50903601825
# MAPE: 0.9871016502264445
# 26/26 [==============================] - 0s 3ms/step
# Scores obtidos:
# RMSE: 231573.6843377248
# MAE: 146991.23800551906
# MAPE: 0.9887276720646663

# %% [markdown]
# #### com relu e 100 epochs
# Scores obtidos:
# - RMSE: 59454.22621021336
# - MAE: 35407.85196496212
# - MAPE: 0.5238617953092802

# %%
set_seeds(41)

x,y = load_data()

timestep=3

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, activation="relu")),
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 1s 3ms/step
# Scores obtidos:
# RMSE: 25465.56046544104
# MAE: 14280.28565143168
# MAPE: 0.13265056384408788
# 26/26 [==============================] - 0s 3ms/step
# Scores obtidos:
# RMSE: 56660.27818819081
# MAE: 31855.62744910038
# MAPE: 0.31278073181543564

# %%
set_seeds(41)

x,y = load_data()

timestep=3

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)

scaler = Scaler3DShape(StandardScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, activation="relu")),
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 1s 4ms/step
# Scores obtidos:
# RMSE: 17363.861734738766
# MAE: 9169.359774612549
# MAPE: 0.08916608573463236
# 26/26 [==============================] - 0s 4ms/step
# Scores obtidos:
# RMSE: 38254.908645048294
# MAE: 24773.27638790246
# MAPE: 0.2737743742287278

# %% [markdown]
# ## 1 camada LSTM (128) e 2 Dense (64 e 32)

# %% [markdown]
# #### 100 epochs e time=5
#
# Scores obtidos:
# - RMSE: 46392.99735975
# - MAE: 27434.907446732956
# - MAPE: 0.32636502789045585

# %%
set_seeds()

x,y = load_data()

timestamp=5

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128)),
model.add(Dense(units=64, activation="relu")),
model.add(Dense(units=32, activation="relu")),
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 26/26 [==============================] - 0s 3ms/step
# Scores obtidos:
# RMSE: 38283.951153544396
# MAE: 23470.476100260417
# MAPE: 0.2518433380576844

# %% [markdown]
# #### 200 epochs

# %% [markdown]
# ##### time = 5
#
# Scores obtidos:
# - RMSE: 45494.32251275807
# - MAE: 27311.896248816287
# - MAPE: 0.3272892025806476

# %%
set_seeds(41)

x,y = load_data()

timestamp=5

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128)),
model.add(Dense(units=64, activation="relu")),
model.add(Dense(units=32, activation="relu")),
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=200, batch_size=32, verbose=0) 

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 26/26 [==============================] - 1s 3ms/step
# Scores obtidos:
# RMSE: 43500.49756738467
# MAE: 25218.21004202178
# MAPE: 0.28308978252871503

# %% [markdown]
# ##### time = 3
#
# Scores obtidos:
# - RMSE: 82434.78071327829
# - MAE: 33151.49016970592
# - MAPE: 0.2897967056520212

# %%
set_seeds(41)

x,y = load_data()

timestamp=3

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128)),
model.add(Dense(units=64, activation="relu")),
model.add(Dense(units=32, activation="relu")),
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=200, batch_size=32, verbose=0) 

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 26/26 [==============================] - 1s 4ms/step
# Scores obtidos:
# RMSE: 43500.49756738467
# MAE: 25218.21004202178
# MAPE: 0.28308978252871503

# %% [markdown]
# ## 2 LSTM (128, 64)

# %% [markdown]
# #### time=3
#
# Scores obtidos:
# - RMSE: 47937.57608701416
# - MAE: 30520.58515506629
# - MAPE: 0.6034912735397143

# %%
set_seeds(41)

x,y = load_data()

timestep=3

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 1s 5ms/step
# Scores obtidos:
# RMSE: 27711.121564791018
# MAE: 15349.101068602315
# MAPE: 0.127521435506781
# 26/26 [==============================] - 0s 5ms/step
# Scores obtidos:
# RMSE: 39590.881116231925
# MAE: 24214.136155894885
# MAPE: 0.25949729264790766

# %% [markdown]
# #### tempo=5
#
# Scores obtidos:
# - RMSE: 93866.71545072406
# - MAE: 41651.13536485229
# - MAPE: 0.39764072258143845

# %%
set_seeds(41)

x,y = load_data()

timestep=5

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)


scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 1s 7ms/step
# Scores obtidos:
# RMSE: 30829.321748368726
# MAE: 17676.5785151932
# MAPE: 0.17652814242535936
# 26/26 [==============================] - 0s 7ms/step
# Scores obtidos:
# RMSE: 87907.06277973273
# MAE: 40267.389034971144
# MAPE: 0.3651181170279886

# %% [markdown]
# #### 200 epochs
#
# Scores obtidos:
# - RMSE: 62765.941925364394
# - MAE: 31246.32063584542
# - MAPE: 0.3155484887742061

# %%
set_seeds(41)

x,y = load_data()

timestep=5

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=200, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 1s 3ms/step
# Scores obtidos:
# RMSE: 26947.06657813177
# MAE: 15127.280170327575
# MAPE: 0.11992147400439133
# 26/26 [==============================] - 0s 3ms/step
# Scores obtidos:
# RMSE: 57328.25822660699
# MAE: 27607.40220907218
# MAPE: 0.2401585684654739

# %% [markdown]
# ### 3 LSTM (256,128,64)
#
# Scores obtidos:
# - RMSE: 98186.6575856922
# - MAE: 43614.27450542983
# - MAPE: 0.43116302614299745

# %%
set_seeds(41)

x,y = load_data()

timestep=5

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)


scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=256, return_sequences=True, activation="relu")),
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 2s 9ms/step
# Scores obtidos:
# RMSE: 30384.872244903516
# MAE: 17830.75315925256
# MAPE: 0.1814343637153943
# 26/26 [==============================] - 0s 8ms/step
# Scores obtidos:
# RMSE: 88233.40791675252
# MAE: 39646.65394445816
# MAPE: 0.36737721967030806

# %% [markdown]
# ### 2 LSTM (128,64) e 2 Dense (64,32)

# %% [markdown]
# #### 100 epochs
#
# Scores obtidos:
# - RMSE: 87501.27268699308
# - MAE: 44313.45026176147
# - MAPE: 0.4376272877939251

# %%
set_seeds(41)

x,y = load_data()

timestep=5

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)


scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 1s 6ms/step
# Scores obtidos:
# RMSE: 41061.50390599017
# MAE: 26636.199924762303
# MAPE: 0.2630063807807765
# 26/26 [==============================] - 0s 6ms/step
# Scores obtidos:
# RMSE: 85837.55928007865
# MAE: 43231.23481641099
# MAPE: 0.483846041862308

# %% [markdown]
# #### 200 epochs
#
# Scores obtidos:
# - RMSE: 61438.50519587389
# - MAE: 35990.8339950543
# - MAPE: 0.3461413386155613

# %%
set_seeds(41)

x,y = load_data()

timestep=5

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)


scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=200, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 2s 7ms/step
# Scores obtidos:
# RMSE: 25014.380147864304
# MAE: 13728.831392886734
# MAPE: 0.1104006659636472
# 26/26 [==============================] - 0s 7ms/step
# Scores obtidos:
# RMSE: 49410.86714502776
# MAE: 27183.550057430894
# MAPE: 0.2897464252560437

# %% [markdown]
# #### time=3
#
# Scores obtidos:
# - RMSE: 47664.22333572863
# - MAE: 28967.3253515625
# - MAPE: 0.3412079531803263

# %%
set_seeds(41)

x,y = load_data()

timestep=3

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)


scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 1s 5ms/step
# Scores obtidos:
# RMSE: 29762.919145025775
# MAE: 15810.68985762182
# MAPE: 0.1194647127443595
# 26/26 [==============================] - 0s 7ms/step
# Scores obtidos:
# RMSE: 45648.09440561886
# MAE: 26804.582781723486
# MAPE: 0.2749037487445539

# %%
set_seeds(41)

x,y = load_data()

timestep=3

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)


scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=200, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 1s 4ms/step
# Scores obtidos:
# RMSE: 24016.05053031812
# MAE: 12361.050626687227
# MAPE: 0.10534124507998999
# 26/26 [==============================] - 0s 5ms/step
# Scores obtidos:
# RMSE: 59337.12960916693
# MAE: 34167.194398082385
# MAPE: 0.32275146866635135

# %% [markdown]
# ### Dropando estados
#
# Scores obtidos:
# - RMSE: 43284.24108503721
# - MAE: 25254.01914620197
# - MAPE: 0.30587778476142785

# %%
DROP=['estados_AL', 'estados_AM', 'estados_AP', 'estados_BA', 'estados_CE',
       'estados_DF', 'estados_ES', 'estados_GO', 'estados_MA', 'estados_MG',
       'estados_MS', 'estados_MT', 'estados_PA', 'estados_PB', 'estados_PE',
       'estados_PI', 'estados_PR', 'estados_RJ', 'estados_RN', 'estados_RO',
       'estados_RR', 'estados_RS', 'estados_SC', 'estados_SE', 'estados_SP',
       'estados_TO']

set_seeds(41)

x,y = load_data()

x=x.drop(DROP, axis=1)

timestep=5

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=200, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 2s 7ms/step
# Scores obtidos:
# RMSE: 27045.586858189876
# MAE: 16073.803847135503
# MAPE: 0.14168969599520273
# 26/26 [==============================] - 0s 7ms/step
# Scores obtidos:
# RMSE: 46856.611790292176
# MAE: 28304.83325046989
# MAPE: 0.30252766004626225

# %%
DROP=['estados_AL', 'estados_AM', 'estados_AP', 'estados_BA', 'estados_CE',
       'estados_DF', 'estados_ES', 'estados_GO', 'estados_MA', 'estados_MG',
       'estados_MS', 'estados_MT', 'estados_PA', 'estados_PB', 'estados_PE',
       'estados_PI', 'estados_PR', 'estados_RJ', 'estados_RN', 'estados_RO',
       'estados_RR', 'estados_RS', 'estados_SC', 'estados_SE', 'estados_SP',
       'estados_TO']

set_seeds(41)

x,y = load_data()

x=x.drop(DROP, axis=1)

timestep=3

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=200, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 2s 4ms/step
# Scores obtidos:
# RMSE: 24445.05874564924
# MAE: 12969.95404024304
# MAPE: 0.1356811650028448
# 26/26 [==============================] - 0s 5ms/step
# Scores obtidos:
# RMSE: 43146.54015085138
# MAE: 27611.235627811315
# MAPE: 0.30827546999642425

# %% [markdown]
# ### Dropando variáveis de alta correlação
#
# Scores obtidos:
# - RMSE: 58213.67482213611
# - MAE: 38204.95383176189
# - MAPE: 0.38724930313419637

# %%
DROP=['pib_pc', 'incc','igp', 'selic', 'idh_e', 'idh_l', 'nfsp','preco_saco', 'preco_ton', 'estoque']

set_seeds(41)

x,y = load_data()

x=x.drop(DROP, axis=1)

timestep=5

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=200, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 2s 8ms/step
# Scores obtidos:
# RMSE: 52440.47281577931
# MAE: 29528.153482661994
# MAPE: 0.21414876963527063
# 26/26 [==============================] - 0s 9ms/step
# Scores obtidos:
# RMSE: 55304.97560683588
# MAE: 33828.68676342507
# MAPE: 0.25239662714503674

# %%
DROP=['pib_pc', 'incc','igp', 'selic', 'idh_e', 'idh_l', 'nfsp','preco_saco', 'preco_ton', 'estoque']

set_seeds(41)

x,y = load_data()

x=x.drop(DROP, axis=1)

timestep=5

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="swish")),
model.add(LSTM(units=64, activation="swish")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=200, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 2s 9ms/step
# Scores obtidos:
# RMSE: 42280.91873288205
# MAE: 22340.3128472161
# MAPE: 0.16297478455641745
# 26/26 [==============================] - 0s 13ms/step
# Scores obtidos:
# RMSE: 49112.59521114975
# MAE: 28214.14711742007
# MAPE: 0.23393359982906778

# %% [markdown]
# ### Geomean
#
# Scores obtidos:
# - RMSE: 57604.206358640324
# - MAE: 32618.536871463966
# - MAPE: 0.35017885534503407

# %%
geomean = lambda x, axis : np.exp(np.mean(np.log(x), axis=axis))

set_seeds(41)

x,y = load_data()

x['geomean'] = geomean(x, 1)
#x=x.drop(DROP, axis=1)

timestep=5

df = x.copy()
df["consumo"] = y


df_train, df_test = train_test_split(df, test_size=0.15, shuffle=False)

x_train, y_train = split_sequences(df_train.values, timestep)
x_test, y_test = split_sequences(df_test.values, timestep)

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=200, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 3s 10ms/step
# Scores obtidos:
# RMSE: 28343.771155887345
# MAE: 15694.728631639664
# MAPE: 0.12099809105248671
# 26/26 [==============================] - 0s 9ms/step
# Scores obtidos:
# RMSE: 48741.63335820588
# MAE: 26628.979119005355
# MAPE: 0.28435449033670646

# %% [markdown]
# ### Gráficos

# %%
show_delta(np.array(y_test), y_pred.flatten())
# Out:
#          erro                    categoria
# 0    0.051695             entre -10% e 10%
# 1    0.205491  superestima entre 10% e 30%
# 2   -0.053394             entre -10% e 10%
# 3   -0.020805             entre -10% e 10%
# 4    0.162773  superestima entre 10% e 30%
# ..        ...                          ...
# 818  0.005218             entre -10% e 10%
# 819  0.120127  superestima entre 10% e 30%
# 820 -0.091566             entre -10% e 10%
# 821  0.513083  superestima entre 30% e 60%
# 822  0.753918  superestima entre 60% e 90%
#
# [823 rows x 2 columns]

# %%
def show_graphs (pred, reg):
    
    plt.figure(figsize=(14,6))
    
    
    plt.title("Visão regional")
    
    for state in reg:
        
        sns.scatterplot(pred[pred['estados'] == state]['y_test'], label=f"Dado real de {state}")
        sns.lineplot(pred[pred['estados'] == state]['y_pred'], label=f"Previsão e {state}")
        
    plt.ylabel="Consumo"
        
    plt.show()

# %%
pred = get_pred(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 pred = get_pred(y_test, y_pred)
#
# Input In [9], in get_pred(y_test, y_pred)
#      16 pred['estados'] = SIGLAS * 30
#      18 # garante que todos os estados estao presentes em todas as datas
# ---> 19 pred['y_test'] =  y_test[len(y_test) % 27 :].values
#      20 pred['y_pred'] = y_pred[len(y_pred) % 27 :]
#      22 pred = pred.set_index('data')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
region_metrics(pred)

# %%
region_graphs(pred, 'NORTE')

# %%
region_graphs(pred, 'NORDESTE')

# %%
region_graphs(pred, 'CENTRO OESTE')

# %%
region_graphs(pred, 'SUDESTE')

# %%
region_graphs(pred, 'SUL')

# %% [markdown]
# ### Teste sem variáveis anuais

# %%
x.columns
# Out:
# Index(['pib_pc', 'pib_pmc', 'pib_pcpt', 'pib_cc', 'populacao', 'incc', 'ipca',
#        'igp', 'selic', 'idh_l', 'idh_r', 'idh_e', 'nfsp', 'estoque',
#        'desemprego', 'producao', 'preco_ton', 'preco_saco', 'preco_kg',
#        'estados_AL', 'estados_AM', 'estados_AP', 'estados_BA', 'estados_CE',
#        'estados_DF', 'estados_ES', 'estados_GO', 'estados_MA', 'estados_MG',
#        'estados_MS', 'estados_MT', 'estados_PA', 'estados_PB', 'estados_PE',
#        'estados_PI', 'estados_PR', 'estados_RJ', 'estados_RN', 'estados_RO',
#        'estados_RR', 'estados_RS', 'estados_SC', 'estados_SE', 'estados_SP',
#        'estados_TO'],
#       dtype='object')

# %%
set_seeds(41)

x,y = load_data()

ANUAIS = ['pib_pc', 'pib_pmc', 'pib_pcpt', 'pib_cc', 'populacao',
          'idh_l', 'idh_r', 'idh_e']
x=x.drop(ANUAIS, axis=1)

timestep=5

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.15, shuffle=False)

x_train = split_sequences(x_train.values, timestep)
x_test = split_sequences(x_test.values, timestep)
y_train = y_train[:-timestep+1]
y_test = y_test[:-timestep+1]

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [33], in <cell line: 19>()
#      16 y_test = y_test[:-timestep+1]
#      18 scaler = Scaler3DShape(MinMaxScaler)
# ---> 19 x_train = scaler.fit_transform(x_train)
#      20 x_test = scaler.transform(x_test)
#      22 model = Sequential()
#
# Input In [11], in Scaler3DShape.fit_transform(self, x)
#       6 def fit_transform(self, x):
# ----> 7     x_new = self.scaler.fit_transform(x.reshape(-1, x.shape[-1])).reshape(x.shape)
#       8     return x_new
#
# AttributeError: 'tuple' object has no attribute 'reshape'

# %%
set_seeds(41)

x,y = load_data()

ANUAIS = ['pib_pc',  'pib_pcpt', 'populacao',
          'idh_l', 'idh_r', 'idh_e']
x=x.drop(ANUAIS, axis=1)

timestep=5

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.15, shuffle=False)

x_train = split_sequences(x_train.values, timestep)
x_test = split_sequences(x_test.values, timestep)
y_train = y_train[:-timestep+1]
y_test = y_test[:-timestep+1]

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [34], in <cell line: 19>()
#      16 y_test = y_test[:-timestep+1]
#      18 scaler = Scaler3DShape(MinMaxScaler)
# ---> 19 x_train = scaler.fit_transform(x_train)
#      20 x_test = scaler.transform(x_test)
#      22 model = Sequential()
#
# Input In [11], in Scaler3DShape.fit_transform(self, x)
#       6 def fit_transform(self, x):
# ----> 7     x_new = self.scaler.fit_transform(x.reshape(-1, x.shape[-1])).reshape(x.shape)
#       8     return x_new
#
# AttributeError: 'tuple' object has no attribute 'reshape'

# %%
set_seeds(41)

x,y = load_data()

ANUAIS = ['pib_pc',  'pib_pcpt', 'populacao',
          'idh_l', 'idh_r', 'idh_e']
x=x.drop(ANUAIS, axis=1)

timestep=5

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.15, shuffle=False)

x_train = split_sequences(x_train.values, timestep)
x_test = split_sequences(x_test.values, timestep)
y_train = y_train[:-timestep+1]
y_test = y_test[:-timestep+1]

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)

# %%
set_seeds(41)

x,y = load_data()

ANUAIS = ['idh_l', 'idh_r', 'idh_e', 
          'preco_ton', 'preco_saco']
x=x.drop(ANUAIS, axis=1)

timestep=5

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.15, shuffle=False)

x_train = split_sequences(x_train.values, timestep)
x_test = split_sequences(x_test.values, timestep)
y_train = y_train[:-timestep+1]
y_test = y_test[:-timestep+1]

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 3s 11ms/step
# Scores obtidos:
# RMSE: 34784.345493372544
# MAE: 20505.83523431048
# MAPE: 0.20156511698605556
# 26/26 [==============================] - 0s 16ms/step
# Scores obtidos:
# RMSE: 40772.74700943541
# MAE: 26845.950874041235
# MAPE: 0.36531456605968504

# %%
set_seeds(41)

x,y = load_data()

ANUAIS = ['idh_l', 'idh_r', 'idh_e', 
          'preco_ton', 'preco_saco']
x=x.drop(ANUAIS, axis=1)

timestep=5

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.15, shuffle=False)

x_train = split_sequences(x_train.values, timestep)
x_test = split_sequences(x_test.values, timestep)
y_train = y_train[:-timestep+1]
y_test = y_test[:-timestep+1]

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=200, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 3s 10ms/step
# Scores obtidos:
# RMSE: 31266.9091532243
# MAE: 18136.192057430922
# MAPE: 0.1775957450415339
# 26/26 [==============================] - 0s 9ms/step
# Scores obtidos:
# RMSE: 35267.99602178453
# MAE: 23314.530264538083
# MAPE: 0.306124915185084

# %% [markdown]
# ### com média geométrica

# %%
geomean = lambda x, axis : np.exp(np.mean(np.log(x), axis=axis))

DROP = ['estados_AL', 'estados_AM', 'estados_AP', 'estados_BA', 'estados_CE',
       'estados_DF', 'estados_ES', 'estados_GO', 'estados_MA', 'estados_MG',
       'estados_MS', 'estados_MT', 'estados_PA', 'estados_PB', 'estados_PE',
       'estados_PI', 'estados_PR', 'estados_RJ', 'estados_RN', 'estados_RO',
       'estados_RR', 'estados_RS', 'estados_SC', 'estados_SE', 'estados_SP',
       'estados_TO']
set_seeds(41)

x,y = load_data()

x['geomean'] = geomean(x, 1)
#x['sin'] = np.sin(x)
#x=x.drop(DROP, axis=1)

timestep=5

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.15, shuffle=False)

x_train = split_sequences(x_train.values, timestep)
x_test = split_sequences(x_test.values, timestep)
y_train = y_train[:-timestep+1]
y_test = y_test[:-timestep+1]

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 1s 4ms/step
# Scores obtidos:
# RMSE: 27007.999010280153
# MAE: 15370.224251867516
# MAPE: 0.16777873249993278
# 26/26 [==============================] - 0s 4ms/step
# Scores obtidos:
# RMSE: 34839.01889201264
# MAE: 21083.77745291616
# MAPE: 0.23081189968439703

# %% [markdown]
# ### teste com 300 epochs

# %%
geomean = lambda x, axis : np.exp(np.mean(np.log(x), axis=axis))

DROP = ['estados_AL', 'estados_AM', 'estados_AP', 'estados_BA', 'estados_CE',
       'estados_DF', 'estados_ES', 'estados_GO', 'estados_MA', 'estados_MG',
       'estados_MS', 'estados_MT', 'estados_PA', 'estados_PB', 'estados_PE',
       'estados_PI', 'estados_PR', 'estados_RJ', 'estados_RN', 'estados_RO',
       'estados_RR', 'estados_RS', 'estados_SC', 'estados_SE', 'estados_SP',
       'estados_TO']
set_seeds(41)

x,y = load_data()

#x['geomean'] = geomean(x, 1)
#x['sin'] = np.sin(x)
#x=x.drop(DROP, axis=1)

timestep=5

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.15, shuffle=False)

x_train = split_sequences(x_train.values, timestep)
x_test = split_sequences(x_test.values, timestep)
y_train = y_train[:-timestep+1]
y_test = y_test[:-timestep+1]

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=300, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 2s 9ms/step
# Scores obtidos:
# RMSE: 21102.2682446557
# MAE: 11941.423409985033
# MAPE: 0.1577360425208329
# 26/26 [==============================] - 0s 8ms/step
# Scores obtidos:
# RMSE: 35358.43088853852
# MAE: 23278.400696764886
# MAPE: 0.3253017010112032

# %% [markdown]
# #### teste com Power Transformer

# %% [markdown]
# #### sen com 200 epochs

# %%
geomean = lambda x, axis : np.exp(np.mean(np.log(x), axis=axis))

DROP = ['estados_AL', 'estados_AM', 'estados_AP', 'estados_BA', 'estados_CE',
       'estados_DF', 'estados_ES', 'estados_GO', 'estados_MA', 'estados_MG',
       'estados_MS', 'estados_MT', 'estados_PA', 'estados_PB', 'estados_PE',
       'estados_PI', 'estados_PR', 'estados_RJ', 'estados_RN', 'estados_RO',
       'estados_RR', 'estados_RS', 'estados_SC', 'estados_SE', 'estados_SP',
       'estados_TO']
set_seeds(41)

x,y = load_data()

#x['geomean'] = geomean(x, 1)
x = np.sin(x)
#x=x.drop(DROP, axis=1)

timestep=5

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.15, shuffle=False)

x_train = split_sequences(x_train.values, timestep)
x_test = split_sequences(x_test.values, timestep)
y_train = y_train[:-timestep+1]
y_test = y_test[:-timestep+1]

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)



model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=200, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 2s 10ms/step
# Scores obtidos:
# RMSE: 20683.184408257563
# MAE: 12332.617910813347
# MAPE: 0.10281654934887009
# 26/26 [==============================] - 0s 12ms/step
# Scores obtidos:
# RMSE: 73704.54883247631
# MAE: 44243.54452852085
# MAPE: 0.5265680649511161

# %%
geomean = lambda x, axis : np.exp(np.mean(np.log(x), axis=axis))

DROP = ['estados_AL', 'estados_AM', 'estados_AP', 'estados_BA', 'estados_CE',
       'estados_DF', 'estados_ES', 'estados_GO', 'estados_MA', 'estados_MG',
       'estados_MS', 'estados_MT', 'estados_PA', 'estados_PB', 'estados_PE',
       'estados_PI', 'estados_PR', 'estados_RJ', 'estados_RN', 'estados_RO',
       'estados_RR', 'estados_RS', 'estados_SC', 'estados_SE', 'estados_SP',
       'estados_TO']
set_seeds(41)

x,y = load_data()

#x['geomean'] = geomean(x, 1)
#x = np.sin(x)
#x=x.drop(DROP, axis=1)

timestep=5

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.15, shuffle=False)

st = SplineTransformer(degree=2, n_knots=3)
x_train = st.fit_transform(x_train)
x_test = st.transform(x_test)

x_train = split_sequences(x_train, timestep)
x_test = split_sequences(x_test, timestep)
y_train = y_train[:-timestep+1]
y_test = y_test[:-timestep+1]

#scaler = Scaler3DShape()
# x_train = scaler.fit_transform(x_train)
# x_test = scaler.transform(x_test)



model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=200, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 3s 15ms/step
# Scores obtidos:
# RMSE: 22608.281133652858
# MAE: 12968.160638671876
# MAPE: 0.12160154266393126
# 26/26 [==============================] - 0s 17ms/step
# Scores obtidos:
# RMSE: 45298.63598765199
# MAE: 25494.181542138136
# MAPE: 0.19924231569058387

# %%
geomean = lambda x, axis : np.exp(np.mean(np.log(x), axis=axis))

DROP = ['estados_AL', 'estados_AM', 'estados_AP', 'estados_BA', 'estados_CE',
       'estados_DF', 'estados_ES', 'estados_GO', 'estados_MA', 'estados_MG',
       'estados_MS', 'estados_MT', 'estados_PA', 'estados_PB', 'estados_PE',
       'estados_PI', 'estados_PR', 'estados_RJ', 'estados_RN', 'estados_RO',
       'estados_RR', 'estados_RS', 'estados_SC', 'estados_SE', 'estados_SP',
       'estados_TO']
set_seeds(41)

x,y = load_data()

#x['geomean'] = geomean(x, 1)
#x = np.sin(x)
#x=x.drop(DROP, axis=1)

timestep=5

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.15, shuffle=False)

st = SplineTransformer(degree=2, n_knots=3)
x_train = st.fit_transform(x_train)
x_test = st.transform(x_test)

x_train = split_sequences(x_train, timestep)
x_test = split_sequences(x_test, timestep)
y_train = y_train[:-timestep+1]
y_test = y_test[:-timestep+1]

#scaler = Scaler3DShape()
# x_train = scaler.fit_transform(x_train)
# x_test = scaler.transform(x_test)



model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 4s 16ms/step
# Scores obtidos:
# RMSE: 23341.751216559274
# MAE: 13735.576994444222
# MAPE: 0.18518634167320275
# 26/26 [==============================] - 0s 14ms/step
# Scores obtidos:
# RMSE: 44251.82145660689
# MAE: 25272.89787683684
# MAPE: 0.24571669088815093

# %%
geomean = lambda x, axis : np.exp(np.mean(np.log(x), axis=axis))

DROP = ['estados_AL', 'estados_AM', 'estados_AP', 'estados_BA', 'estados_CE',
       'estados_DF', 'estados_ES', 'estados_GO', 'estados_MA', 'estados_MG',
       'estados_MS', 'estados_MT', 'estados_PA', 'estados_PB', 'estados_PE',
       'estados_PI', 'estados_PR', 'estados_RJ', 'estados_RN', 'estados_RO',
       'estados_RR', 'estados_RS', 'estados_SC', 'estados_SE', 'estados_SP',
       'estados_TO']
set_seeds(41)

x,y = load_data()

#x['geomean'] = geomean(x, 1)
#x = np.sin(x)
#x=x.drop(DROP, axis=1)

timestep=5

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.15, shuffle=False)

st = SplineTransformer(degree=3, n_knots=3)
x_train = st.fit_transform(x_train)
x_test = st.transform(x_test)

x_train = split_sequences(x_train, timestep)
x_test = split_sequences(x_test, timestep)
y_train = y_train[:-timestep+1]
y_test = y_test[:-timestep+1]

#scaler = Scaler3DShape()
# x_train = scaler.fit_transform(x_train)
# x_test = scaler.transform(x_test)



model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 2s 8ms/step
# Scores obtidos:
# RMSE: 27429.723405824196
# MAE: 15052.327320338392
# MAPE: 0.2183976249948517
# 26/26 [==============================] - 0s 5ms/step
# Scores obtidos:
# RMSE: 38229.41910018305
# MAE: 23389.655856052552
# MAPE: 0.27119450661158284

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
set_seeds(41)

x,y = load_data()

timestep=5

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.15, shuffle=False)

x_train = split_sequences(x_train.values, timestep)
x_test = split_sequences(x_test.values, timestep)
y_train = y_train[:-timestep+1]
y_test = y_test[:-timestep+1]

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 3s 12ms/step
# Scores obtidos:
# RMSE: 24702.26887925225
# MAE: 13739.745965291837
# MAPE: 0.15999445002800225
# 26/26 [==============================] - 0s 11ms/step
# Scores obtidos:
# RMSE: 34621.51869485885
# MAE: 21088.461669625227
# MAPE: 0.23828570973079136

# %%
error = show_delta(np.array(y_test), y_pred.flatten())

# %%
error['categoria'].value_counts()
# Out:
# entre -10% e 10%               273
# subestima entre -30% e 10%     181
# superestima entre 10% e 30%    176
# superestima entre 30% e 60%    115
# superestima entre 60% e 90%     34
# superestima mais de 90%         28
# subestima entre -60% e -30%     16
# Name: categoria, dtype: int64

# %%
pred = get_pred(y_test, y_pred)

# %%
pred.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_8c3ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c3ac_level0_col0" class="col_heading level0 col0" >estados</th>
#       <th id="T_8c3ac_level0_col1" class="col_heading level0 col1" >y_test</th>
#       <th id="T_8c3ac_level0_col2" class="col_heading level0 col2" >y_pred</th>
#       <th id="T_8c3ac_level0_col3" class="col_heading level0 col3" >regiao</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >data</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c3ac_level0_row0" class="row_heading level0 row0" >2017-07-01</th>
#       <td id="T_8c3ac_row0_col0" class="data row0 col0" >AC</td>
#       <td id="T_8c3ac_row0_col1" class="data row0 col1" >231359.000000</td>
# ...

# %%
x.columns
# Out:
# Index(['pib_pc', 'pib_pmc', 'pib_pcpt', 'pib_cc', 'populacao', 'incc', 'ipca',
#        'igp', 'selic', 'idh_l', 'idh_r', 'idh_e', 'nfsp', 'estoque',
#        'desemprego', 'producao', 'preco_ton', 'preco_saco', 'preco_kg',
#        'estados_AL', 'estados_AM', 'estados_AP', 'estados_BA', 'estados_CE',
#        'estados_DF', 'estados_ES', 'estados_GO', 'estados_MA', 'estados_MG',
#        'estados_MS', 'estados_MT', 'estados_PA', 'estados_PB', 'estados_PE',
#        'estados_PI', 'estados_PR', 'estados_RJ', 'estados_RN', 'estados_RO',
#        'estados_RR', 'estados_RS', 'estados_SC', 'estados_SE', 'estados_SP',
#        'estados_TO'],
#       dtype='object')

# %%
set_seeds(41)

x,y = load_data()

x = x.drop(['preco_kg'], axis=1)

timestep=5

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.15, shuffle=False)

x_train = split_sequences(x_train.values, timestep)
x_test = split_sequences(x_test.values, timestep)
y_train = y_train[:-timestep+1]
y_test = y_test[:-timestep+1]

scaler = Scaler3DShape(MinMaxScaler)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential()
model.add(LSTM(units=128, return_sequences=True, activation="relu")),
model.add(LSTM(units=64, activation="relu")),
model.add(Dense(units=64))
model.add(Dense(units=32))
model.add(Dropout(rate=0.10))
model.add(Dense(units=1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="RMSE")])


history = model.fit(x_train, y_train, epochs=100, batch_size=32, verbose=0) 

show_scores(score_regression_metrics(y_train, model.predict(x_train)))

y_pred = model.predict(x_test)
scores = score_regression_metrics(y_test, y_pred)
show_scores(scores)
# Out:
# 147/147 [==============================] - 1s 3ms/step
# Scores obtidos:
# RMSE: 29176.661270494515
# MAE: 16102.542100693889
# MAPE: 0.1675793773616286
# 26/26 [==============================] - 0s 4ms/step
# Scores obtidos:
# RMSE: 37354.12704694787
# MAE: 23356.881464535236
# MAPE: 0.26830885220796397
