# %% [markdown]
# # Análise Exploratória dos Dados (EDA)

# %%
# importamos as libs
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
import pandas as pd 
from sklearn.model_selection import train_test_split

# %%
PATH="../dados/input/"

SIGLAS = ['AC', 'AL', 'AM', 'AP', 'BA', 'CE',
  'DF', 'ES', 'GO', 'MA',
  'MG', 'MS', 'MT', 'PA', 'PB',
  'PE', 'PI', 'PR', 'RJ',
  'RN', 'RO', 'RR', 'RS',
  'SC', 'SE', 'SP', 'TO']

# %%
df = pd.read_csv(f"{PATH}input.csv")

# %%
(df.isna().sum()/df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_6395e_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_6395e_row1_col0 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_6395e_row2_col0, #T_6395e_row3_col0, #T_6395e_row4_col0, #T_6395e_row5_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_6395e_row6_col0, #T_6395e_row7_col0, #T_6395e_row8_col0, #T_6395e_row9_col0, #T_6395e_row10_col0, #T_6395e_row11_col0, #T_6395e_row12_col0, #T_6395e_row13_col0, #T_6395e_row14_col0, #T_6395e_row15_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_6395e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6395e_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6395e_level0_row0" class="row_heading level0 row0" >nfsp</th>
#       <td id="T_6395e_row0_col0" class="data row0 col0" >17.142857</td>
#     </tr>
#     <tr>
#       <th id="T_6395e_level0_row1" class="row_heading level0 row1" >selic</th>
#       <td id="T_6395e_row1_col0" class="data row1 col0" >4.047619</td>
#     </tr>
#     <tr>
#       <th id="T_6395e_level0_row2" class="row_heading level0 row2" >populacao</th>
#       <td id="T_6395e_row2_col0" class="data row2 col0" >0.634921</td>
#     </tr>
#     <tr>
#       <th id="T_6395e_level0_row3" class="row_heading level0 row3" >idh_l</th>
#       <td id="T_6395e_row3_col0" class="data row3 col0" >0.634921</td>
#     </tr>
#     <tr>
#       <th id="T_6395e_level0_row4" class="row_heading level0 row4" >idh_r</th>
#       <td id="T_6395e_row4_col0" class="data row4 col0" >0.634921</td>
#     </tr>
#     <tr>
#       <th id="T_6395e_level0_row5" class="row_heading level0 row5" >idh_e</th>
#       <td id="T_6395e_row5_col0" class="data row5 col0" >0.634921</td>
#     </tr>
#     <tr>
#       <th id="T_6395e_level0_row6" class="row_heading level0 row6" >estados</th>
#       <td id="T_6395e_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6395e_level0_row7" class="row_heading level0 row7" >data</th>
#       <td id="T_6395e_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6395e_level0_row8" class="row_heading level0 row8" >pib_pc</th>
#       <td id="T_6395e_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6395e_level0_row9" class="row_heading level0 row9" >pib_pmc</th>
#       <td id="T_6395e_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6395e_level0_row10" class="row_heading level0 row10" >pib_pcpt</th>
#       <td id="T_6395e_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6395e_level0_row11" class="row_heading level0 row11" >pib_cc</th>
#       <td id="T_6395e_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6395e_level0_row12" class="row_heading level0 row12" >incc</th>
#       <td id="T_6395e_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6395e_level0_row13" class="row_heading level0 row13" >ipca</th>
#       <td id="T_6395e_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6395e_level0_row14" class="row_heading level0 row14" >igp</th>
#       <td id="T_6395e_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6395e_level0_row15" class="row_heading level0 row15" >estoque</th>
#       <td id="T_6395e_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.head()
# Out:
#   estados        data         pib_pc   pib_pmc  pib_pcpt         pib_cc  \
# 0      AC  1985-01-01  271996.683911  0.000052   0.76797  207486.441959
# 1      AC  1985-02-01  271996.683911  0.000052   0.76797  207486.441959
# 2      AC  1985-03-01  271996.683911  0.000052   0.76797  207486.441959
# 3      AC  1985-04-01  271996.683911  0.000052   0.76797  207486.441959
# 4      AC  1985-05-01  271996.683911  0.000052   0.76797  207486.441959
#
#    populacao   incc   ipca    igp  selic  idh_l  idh_r  idh_e  nfsp  \
# 0        NaN   7.53  11.76  12.64    NaN    NaN    NaN    NaN   NaN
# 1        NaN  13.05  23.90  10.16    NaN    NaN    NaN    NaN   NaN
# 2        NaN  11.59  36.49  12.71    NaN    NaN    NaN    NaN   NaN
# 3        NaN   8.80  47.68   7.22    NaN    NaN    NaN    NaN   NaN
# 4        NaN  22.42  58.31   7.78    NaN    NaN    NaN    NaN   NaN
#
#         estoque  desemprego
# 0  3.799125e+06         NaN
# 1  3.799125e+06         NaN
# 2  3.799125e+06         NaN
# 3  3.799125e+06         NaN
# 4  3.799125e+06         NaN

# %%
df = df[df["data"] >= "1991-01-01"].reset_index(drop=True)

# %%
(df.isna().sum()/df.shape[0] * 100).sort_values(ascending=False).to_frame(
    name="Missing (%)"
).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_1304d_row0_col0, #T_1304d_row1_col0, #T_1304d_row2_col0, #T_1304d_row3_col0, #T_1304d_row4_col0, #T_1304d_row5_col0, #T_1304d_row6_col0, #T_1304d_row7_col0, #T_1304d_row8_col0, #T_1304d_row9_col0, #T_1304d_row10_col0, #T_1304d_row11_col0, #T_1304d_row12_col0, #T_1304d_row13_col0, #T_1304d_row14_col0, #T_1304d_row15_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_1304d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1304d_level0_col0" class="col_heading level0 col0" >Missing (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1304d_level0_row0" class="row_heading level0 row0" >estados</th>
#       <td id="T_1304d_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1304d_level0_row1" class="row_heading level0 row1" >data</th>
#       <td id="T_1304d_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1304d_level0_row2" class="row_heading level0 row2" >pib_pc</th>
#       <td id="T_1304d_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1304d_level0_row3" class="row_heading level0 row3" >pib_pmc</th>
#       <td id="T_1304d_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1304d_level0_row4" class="row_heading level0 row4" >pib_pcpt</th>
#       <td id="T_1304d_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1304d_level0_row5" class="row_heading level0 row5" >pib_cc</th>
#       <td id="T_1304d_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1304d_level0_row6" class="row_heading level0 row6" >populacao</th>
#       <td id="T_1304d_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1304d_level0_row7" class="row_heading level0 row7" >incc</th>
#       <td id="T_1304d_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1304d_level0_row8" class="row_heading level0 row8" >ipca</th>
#       <td id="T_1304d_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1304d_level0_row9" class="row_heading level0 row9" >igp</th>
#       <td id="T_1304d_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1304d_level0_row10" class="row_heading level0 row10" >selic</th>
#       <td id="T_1304d_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1304d_level0_row11" class="row_heading level0 row11" >idh_l</th>
#       <td id="T_1304d_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1304d_level0_row12" class="row_heading level0 row12" >idh_r</th>
#       <td id="T_1304d_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1304d_level0_row13" class="row_heading level0 row13" >idh_e</th>
#       <td id="T_1304d_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1304d_level0_row14" class="row_heading level0 row14" >nfsp</th>
#       <td id="T_1304d_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1304d_level0_row15" class="row_heading level0 row15" >estoque</th>
#       <td id="T_1304d_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9396 entries, 0 to 9395
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   estados    9396 non-null   object
#  1   data       9396 non-null   object
#  2   pib_pc     9396 non-null   float64
#  3   pib_pmc    9396 non-null   float64
#  4   pib_pcpt   9396 non-null   float64
#  5   pib_cc     9396 non-null   float64
#  6   populacao  9396 non-null   float64
#  7   incc       9396 non-null   float64
#  8   ipca       9396 non-null   float64
#  9   igp        9396 non-null   float64
#  10  selic      9396 non-null   float64
#  11  idh_l      9396 non-null   float64
#  12  idh_r      9396 non-null   float64
#  13  idh_e      9396 non-null   float64
#  14  nfsp       9396 non-null   float64
#  15  estoque    9396 non-null   float64
# dtypes: float64(14), object(2)
# memory usage: 1.1+ MB

# %%
df.describe().T
# Out:
#             count          mean           std           min           25%  \
# pib_pc     9396.0  8.884727e+06  1.546512e+07  2.223599e+05  1.639188e+06
# pib_pmc    9396.0  7.740387e+06  1.729196e+07  4.712304e+00  6.250891e+05
# pib_pcpt   9396.0  1.110849e+00  6.659869e-01  3.445102e-01  6.778617e-01
# pib_cc     9396.0  6.355513e+06  1.012706e+07  2.293989e+03  1.293523e+06
# populacao  9396.0  6.677788e+06  7.956398e+06  2.175830e+05  2.169688e+06
# incc       9396.0  3.894282e+00  9.559014e+00 -5.000000e-01  2.975000e-01
# ipca       9396.0  6.740652e+01  2.416155e+02  2.900000e-01  2.045000e+00
# igp        9396.0  3.878477e+00  9.252582e+00 -1.240000e+00  2.300000e-01
# selic      9396.0  2.006583e-01  4.000198e-01  1.781129e-02  4.164407e-02
# idh_l      9396.0  7.304342e-01  8.184223e-02  5.510000e-01  6.760000e-01
# idh_r      9396.0  6.525032e-01  7.667451e-02  4.780000e-01  6.010000e-01
# idh_e      9396.0  4.587126e-01  1.956223e-01  1.550000e-01  3.010000e-01
# nfsp       9396.0  3.864540e+00  6.648523e+00 -7.000000e-02  7.575000e-01
# estoque    9396.0  6.411083e+06  9.760824e+05  4.782147e+06  5.656167e+06
#
#                     50%           75%           max
# pib_pc     3.885204e+06  8.752338e+06  9.546031e+07
# pib_pmc    2.440144e+06  7.458359e+06  1.646092e+08
# pib_pcpt   9.293817e-01  1.353092e+00  3.999760e+00
# pib_cc     2.843779e+06  6.931119e+06  6.351618e+07
# populacao  3.474998e+06  8.513497e+06  4.591905e+07
# incc       5.750000e-01  1.122500e+00  5.571000e+01
# ipca       3.750000e+00  6.580000e+00  2.477150e+03
# igp        6.800000e-01  1.462500e+00  4.658000e+01
# selic      5.940236e-02  8.976048e-02  2.029579e+00
# idh_l      7.400000e-01  8.000000e-01  8.900000e-01
# idh_r      6.540000e-01  6.960000e-01  8.630000e-01
# idh_e      4.260000e-01  6.530000e-01  8.400000e-01
# nfsp       1.505000e+00  2.742500e+00  3.824000e+01
# estoque    6.344077e+06  7.283723e+06  7.827728e+06

# %%
corr_matrix = df.corr(method="pearson").abs()

sol = (
    corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
    .stack()
    .sort_values(ascending=False)
)

sol[sol >= 0.70]
# Out:
# C:\Users\julia\AppData\Local\Temp\ipykernel_9932\846124379.py:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
# igp       selic        0.979787
# incc      igp          0.973572
#           selic        0.972561
# pib_pc    pib_cc       0.952784
#           populacao    0.950439
# pib_cc    populacao    0.932531
# igp       nfsp         0.924957
# idh_l     idh_e        0.923898
# selic     nfsp         0.913663
# incc      nfsp         0.897863
# idh_l     idh_r        0.873916
# idh_e     estoque      0.855610
# pib_pc    pib_pmc      0.848182
# pib_pcpt  idh_r        0.795270
# pib_pmc   populacao    0.792921
# idh_r     idh_e        0.786137
# idh_l     estoque      0.771353
# pib_pmc   pib_cc       0.730437
# dtype: float64

# %%
df_corr = df.corr(method="pearson")

labels = np.where(
    np.abs(df_corr) >= 0.75, np.round(df_corr[np.abs(df_corr) > 0.75], 2), ""
)

# plt.figure(figsize=(17, 13))
fig, ax = plt.subplots(figsize=(18, 10))

sns.heatmap(
    df_corr,
    mask=np.triu(np.ones_like(df_corr, dtype=bool)),
    square=False,
    center=0,
    annot=labels,
    fmt="",
    linewidths=0.5,
    cmap="vlag",
    cbar_kws={"shrink": 0.8},
    ax=ax,
)

plt.tight_layout()

# %% [markdown]
# # Consumo

# %%
df = pd.read_csv("https://raw.githubusercontent.com/LeiteJu/TCC/main/data/csv/target_abs.csv")

# %%
df.head()
# Out:
#      data      AC       AL       AM      AP        BA       CE       DF  \
# 0  199001  1450.0  27421.0  21819.0   275.0   98829.0  47569.0  32020.0
# 1  199002   938.0  20324.0  22683.0  1000.0   79133.0  42856.0  31612.0
# 2  199003  1160.0  18584.0  13819.0  1100.0   72574.0  22004.0  37038.0
# 3  199004     0.0  20972.0  16168.0  1000.0   77964.0  29635.0  32340.0
# 4  199005  1643.0  30874.0  22104.0  2015.0  102595.0  45320.0  34414.0
#
#         ES       GO  ...        PR        RJ       RN       RO      RR  \
# 0  52437.0  57264.0  ...  142103.0  221533.0  19353.0   9903.0  2040.0
# 1  36737.0  65472.0  ...  125305.0  183828.0  15043.0   8953.0  2029.0
# 2  40234.0  58816.0  ...  112970.0  182124.0  10654.0   6200.0  2367.0
# 3  40937.0  56475.0  ...  113938.0  172505.0  11015.0   3774.0   751.0
# 4  53728.0  73296.0  ...  146154.0  241736.0  10916.0  11742.0  1774.0
#
#          RS       SC       SE        SP      TO
# 0  138590.0  91667.0  23721.0  639210.0  3258.0
# 1   89165.0  65132.0  14096.0  593101.0  2958.0
# 2  109681.0  75893.0  14728.0  573829.0  3735.0
# 3  108513.0  78178.0  15560.0  549760.0  2866.0
# 4  138613.0  95485.0  19020.0  676138.0  7227.0
#
# [5 rows x 28 columns]

# %%
df['data'] = pd.to_datetime(df['data'], format="%Y%m")

# %%
df.head()
# Out:
#         data      AC       AL       AM      AP        BA       CE       DF  \
# 0 1990-01-01  1450.0  27421.0  21819.0   275.0   98829.0  47569.0  32020.0
# 1 1990-02-01   938.0  20324.0  22683.0  1000.0   79133.0  42856.0  31612.0
# 2 1990-03-01  1160.0  18584.0  13819.0  1100.0   72574.0  22004.0  37038.0
# 3 1990-04-01     0.0  20972.0  16168.0  1000.0   77964.0  29635.0  32340.0
# 4 1990-05-01  1643.0  30874.0  22104.0  2015.0  102595.0  45320.0  34414.0
#
#         ES       GO  ...        PR        RJ       RN       RO      RR  \
# 0  52437.0  57264.0  ...  142103.0  221533.0  19353.0   9903.0  2040.0
# 1  36737.0  65472.0  ...  125305.0  183828.0  15043.0   8953.0  2029.0
# 2  40234.0  58816.0  ...  112970.0  182124.0  10654.0   6200.0  2367.0
# 3  40937.0  56475.0  ...  113938.0  172505.0  11015.0   3774.0   751.0
# 4  53728.0  73296.0  ...  146154.0  241736.0  10916.0  11742.0  1774.0
#
#          RS       SC       SE        SP      TO
# 0  138590.0  91667.0  23721.0  639210.0  3258.0
# 1   89165.0  65132.0  14096.0  593101.0  2958.0
# 2  109681.0  75893.0  14728.0  573829.0  3735.0
# 3  108513.0  78178.0  15560.0  549760.0  2866.0
# 4  138613.0  95485.0  19020.0  676138.0  7227.0
#
# [5 rows x 28 columns]

# %%
df = df.set_index("data")

# %%
plt.figure(figsize=(24,45))

for state in range(27):

    plt.subplot(9,3,state+1)

    plt.title (f"Consumo do estado {SIGLAS[state]}")

    consumo = df[SIGLAS[state]]

    plt.scatter(df.index,df[SIGLAS[state]], color="coral")

plt.show()
