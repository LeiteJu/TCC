# %% [markdown]
# # Data prep
#
# Esse notebook desloca os dados em um ano ou um mês, dependendo do indicador

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PATH="https://raw.githubusercontent.com/LeiteJu/TCC/main/dados/input/"

x = pd.read_csv(f"{PATH}features.csv")
x = x.sort_values(["data", "estados"])

y = pd.read_csv(f"{PATH}target.csv")
y['data'] = pd.to_datetime(y['data'])

# %%
ANUAL = [ 'pib_pc', 'pib_pmc', 'pib_pcpt', 'pib_cc',
          'populacao', 'idh_l', 'idh_r', 'idh_e', 'desemprego']
MENSAL = ['incc', 'ipca', 'igp', 'selic', 'nfsp',
           'estoque', 'producao', 'preco_ton', 'preco_saco',
           'preco_kg']

# %%
NULL = -1

# %%
df = x.copy()
df['data'] = pd.to_datetime(df['data'])
df=df.reset_index(drop=True)

# %%
df.head()
# Out:
#   estados       data        pib_pc       pib_pmc  pib_pcpt        pib_cc  \
# 0      AC 2002-01-01  4.342234e+05  2.285692e+05  0.739806  5.065002e+05
# 1      AL 2002-01-01  1.677938e+06  8.832433e+05  0.581097  1.037095e+06
# 2      AM 2002-01-01  2.883869e+06  1.518029e+06  0.973688  2.401570e+06
# 3      AP 2002-01-01  4.708095e+05  2.478276e+05  0.911519  3.136418e+05
# 4      BA 2002-01-01  7.990762e+06  4.206227e+06  0.599762  7.050330e+06
#
#     populacao  incc  ipca   igp  ...  idh_l  idh_r  idh_e  nfsp       estoque  \
# 0    586942.0  0.36  0.52  0.19  ...  0.694  0.612  0.325   1.9  6.098524e+06
# 1   2887535.0  0.36  0.52  0.19  ...  0.647  0.574  0.282   1.9  6.098524e+06
# 2   2961801.0  0.36  0.52  0.19  ...  0.692  0.608  0.324   1.9  6.098524e+06
# 3    516511.0  0.36  0.52  0.19  ...  0.711  0.638  0.424   1.9  6.098524e+06
# 4  13323212.0  0.36  0.52  0.19  ...  0.680  0.594  0.332   1.9  6.098524e+06
#
#    desemprego  producao   preco_ton  preco_saco  preco_kg
# 0    6.582788       NaN         NaN         NaN       NaN
# 1    9.080515       NaN  105.134783        12.5      0.25
# 2   12.966133       NaN  134.572522        16.0      0.32
# 3   20.539464       NaN         NaN         NaN       NaN
# 4   10.735432       NaN  100.929391        12.0      0.24
#
# [5 rows x 21 columns]

# %%
df = pd.merge(df, y, how='left', on=['data', 'estados'])

# %%
df_sorted = df.sort_values(by=["estados", "data"]).copy()
for estado in df.estados.unique():
    indexes = df_sorted[df_sorted["estados"] == estado].index
    df_sorted.loc[indexes, ANUAL] = df_sorted.loc[indexes, ANUAL].shift(12)
    df_sorted.loc[indexes, MENSAL] = df_sorted.loc[indexes, MENSAL].shift(1)

# %%
df_sorted.head(15)
# Out:
#     estados       data         pib_pc        pib_pmc  pib_pcpt         pib_cc  \
# 0        AC 2002-01-01            NaN            NaN       NaN            NaN
# 27       AC 2002-02-01            NaN            NaN       NaN            NaN
# 54       AC 2002-03-01            NaN            NaN       NaN            NaN
# 81       AC 2002-04-01            NaN            NaN       NaN            NaN
# 108      AC 2002-05-01            NaN            NaN       NaN            NaN
# 135      AC 2002-06-01            NaN            NaN       NaN            NaN
# 162      AC 2002-07-01            NaN            NaN       NaN            NaN
# 189      AC 2002-08-01            NaN            NaN       NaN            NaN
# 216      AC 2002-09-01            NaN            NaN       NaN            NaN
# 243      AC 2002-10-01            NaN            NaN       NaN            NaN
# 270      AC 2002-11-01            NaN            NaN       NaN            NaN
# 297      AC 2002-12-01            NaN            NaN       NaN            NaN
# 324      AC 2003-01-01  434223.352964  228569.188542  0.739806  506500.171013
# 351      AC 2003-02-01  434223.352964  228569.188542  0.739806  506500.171013
# 378      AC 2003-03-01  434223.352964  228569.188542  0.739806  506500.171013
#
#      populacao  incc   ipca   igp  ...  idh_r  idh_e  nfsp       estoque  \
# 0          NaN   NaN    NaN   NaN  ...    NaN    NaN   NaN           NaN
# 27         NaN  0.36   0.52  0.19  ...    NaN    NaN  1.90  6.098524e+06
# 54         NaN  0.58   0.88  0.18  ...    NaN    NaN  1.79  6.098524e+06
# 81         NaN  0.55   1.49  0.11  ...    NaN    NaN  1.79  6.098524e+06
# 108        NaN  0.33   2.30  0.70  ...    NaN    NaN  1.65  6.098524e+06
# 135        NaN  2.53   2.51  1.11  ...    NaN    NaN  1.55  6.098524e+06
# 162        NaN  0.57   2.94  1.74  ...    NaN    NaN  1.77  6.098524e+06
# 189        NaN  0.29   4.17  2.05  ...    NaN    NaN  1.98  6.098524e+06
# 216        NaN  1.00   4.85  2.36  ...    NaN    NaN  1.77  6.098524e+06
# 243        NaN  0.71   5.60  2.64  ...    NaN    NaN  2.15  6.098524e+06
# 270        NaN  1.13   6.98  4.21  ...    NaN    NaN  2.18  6.098524e+06
# 297        NaN  2.45  10.22  5.84  ...    NaN    NaN  2.46  6.098524e+06
# 324   586942.0  1.70  12.53  2.70  ...  0.612  0.325  3.46  6.098524e+06
# 351   586942.0  1.51   2.25  2.17  ...  0.612  0.325  3.59  6.172460e+06
# 378   586942.0  1.39   3.86  1.59  ...  0.612  0.325  3.84  6.172460e+06
#
#      desemprego  producao  preco_ton  preco_saco  preco_kg  consumo
# 0           NaN       NaN        NaN         NaN       NaN      NaN
# 27          NaN       NaN        NaN         NaN       NaN      NaN
# 54          NaN       NaN        NaN         NaN       NaN      NaN
# 81          NaN       NaN        NaN         NaN       NaN      NaN
# 108         NaN       NaN        NaN         NaN       NaN      NaN
# 135         NaN       NaN        NaN         NaN       NaN      NaN
# 162         NaN       NaN        NaN         NaN       NaN      NaN
# 189         NaN       NaN        NaN         NaN       NaN      NaN
# 216         NaN       NaN        NaN         NaN       NaN      NaN
# 243         NaN       NaN        NaN         NaN       NaN      NaN
# 270         NaN       NaN        NaN         NaN       NaN      NaN
# 297         NaN       NaN        NaN         NaN       NaN      NaN
# 324    6.582788       NaN        NaN         NaN       NaN   3260.0
# 351    6.582788       NaN        NaN         NaN       NaN   2191.0
# 378    6.582788       NaN        NaN         NaN       NaN   2154.0
#
# [15 rows x 22 columns]

# %%
df_sorted = df_sorted.fillna(NULL)

# %%
df_sorted = df_sorted[df_sorted['data'].dt.year >= 2003]

# %%
df_sorted.head(10)
# Out:
#     estados       data         pib_pc        pib_pmc  pib_pcpt         pib_cc  \
# 324      AC 2003-01-01  434223.352964  228569.188542  0.739806  506500.171013
# 351      AC 2003-02-01  434223.352964  228569.188542  0.739806  506500.171013
# 378      AC 2003-03-01  434223.352964  228569.188542  0.739806  506500.171013
# 405      AC 2003-04-01  434223.352964  228569.188542  0.739806  506500.171013
# 432      AC 2003-05-01  434223.352964  228569.188542  0.739806  506500.171013
# 459      AC 2003-06-01  434223.352964  228569.188542  0.739806  506500.171013
# 486      AC 2003-07-01  434223.352964  228569.188542  0.739806  506500.171013
# 513      AC 2003-08-01  434223.352964  228569.188542  0.739806  506500.171013
# 540      AC 2003-09-01  434223.352964  228569.188542  0.739806  506500.171013
# 567      AC 2003-10-01  434223.352964  228569.188542  0.739806  506500.171013
#
#      populacao  incc   ipca   igp  ...  idh_r  idh_e  nfsp       estoque  \
# 324   586942.0  1.70  12.53  2.70  ...  0.612  0.325  3.46  6.098524e+06
# 351   586942.0  1.51   2.25  2.17  ...  0.612  0.325  3.59  6.172460e+06
# 378   586942.0  1.39   3.86  1.59  ...  0.612  0.325  3.84  6.172460e+06
# 405   586942.0  1.38   5.13  1.66  ...  0.612  0.325  3.95  6.172460e+06
# 432   586942.0  0.90   6.15  0.41  ...  0.612  0.325  4.06  6.172460e+06
# 459   586942.0  2.84   6.80 -0.67  ...  0.612  0.325  3.94  6.172460e+06
# 486   586942.0  1.05   6.64 -0.70  ...  0.612  0.325  3.60  6.172460e+06
# 513   586942.0  0.99   6.85 -0.20  ...  0.612  0.325  3.23  6.172460e+06
# 540   586942.0  1.44   7.22  0.62  ...  0.612  0.325  3.17  6.172460e+06
# 567   586942.0  0.22   8.05  1.05  ...  0.612  0.325  2.70  6.172460e+06
#
#      desemprego  producao  preco_ton  preco_saco  preco_kg  consumo
# 324    6.582788      -1.0       -1.0        -1.0      -1.0   3260.0
# 351    6.582788      -1.0       -1.0        -1.0      -1.0   2191.0
# 378    6.582788      -1.0       -1.0        -1.0      -1.0   2154.0
# 405    6.582788   34655.0       -1.0        -1.0      -1.0   2643.0
# 432    6.582788  172597.0       -1.0        -1.0      -1.0   2546.0
# 459    6.582788   28018.0       -1.0        -1.0      -1.0   3040.0
# 486    6.582788   45130.0       -1.0        -1.0      -1.0   4963.0
# 513    6.582788  345698.0       -1.0        -1.0      -1.0   2924.0
# 540    6.582788   44543.0       -1.0        -1.0      -1.0   5276.0
# 567    6.582788  187848.0       -1.0        -1.0      -1.0   5262.0
#
# [10 rows x 22 columns]

# %%
df_sorted.to_csv('../dados/input/df.csv', index=False)
