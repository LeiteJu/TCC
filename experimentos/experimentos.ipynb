# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # MLP

# %% [markdown]
# ## 1 camada

# %%
df = pd.read_csv("mlp_1c.csv")

# %%
df.head()
# Out:
#    bi_lstm  dense  epochs neuronios  \
# 0        1     50     256      relu
# 1        1     50     256      relu
# 2        1     50     256      relu
# 3        1     50     256     swish
# 4        1     50     256     swish
#
#                                        ativacao_lstm  ativacao_normal  \
# 0  <class 'sklearn.preprocessing._data.StandardSc...     56061.402789
# 1  <class 'sklearn.preprocessing._data.MinMaxScal...     97335.369601
# 2  <class 'sklearn.preprocessing._data.PowerTrans...     57810.626841
# 3  <class 'sklearn.preprocessing._data.StandardSc...     80208.466471
# 4  <class 'sklearn.preprocessing._data.MinMaxScal...     97556.931119
#
#     normalizacao       mae  rmse  mape
# 0   92126.911487  0.581974   NaN   NaN
# 1  172628.009601  1.254184   NaN   NaN
# 2  105452.895209  0.617094   NaN   NaN
# 3  133189.325813  0.655458   NaN   NaN
# 4  176016.636952  1.160719   NaN   NaN

# %%
df = df.drop(["rmse", "mape"], axis=1)

# %%
df.columns = ["camadas", "epochs", "neuronios", "ativacao", "scaler", "mae", "rmse","mape"]

# %%
df.head()
# Out:
#    camadas  epochs  neuronios ativacao  \
# 0        1      50        256     relu
# 1        1      50        256     relu
# 2        1      50        256     relu
# 3        1      50        256    swish
# 4        1      50        256    swish
#
#                                               scaler           mae  \
# 0  <class 'sklearn.preprocessing._data.StandardSc...  56061.402789
# 1  <class 'sklearn.preprocessing._data.MinMaxScal...  97335.369601
# 2  <class 'sklearn.preprocessing._data.PowerTrans...  57810.626841
# 3  <class 'sklearn.preprocessing._data.StandardSc...  80208.466471
# 4  <class 'sklearn.preprocessing._data.MinMaxScal...  97556.931119
#
#             rmse      mape
# 0   92126.911487  0.581974
# 1  172628.009601  1.254184
# 2  105452.895209  0.617094
# 3  133189.325813  0.655458
# 4  176016.636952  1.160719

# %%
df[df['mape'] == df['mape'].min()]
# Out:
#     camadas  epochs  neuronios ativacao  \
# 48        1     150        256     relu
#
#                                                scaler           mae  \
# 48  <class 'sklearn.preprocessing._data.StandardSc...  51665.374582
#
#             rmse      mape
# 48  87660.116456  0.496628

# %%
df[df['mae'] == df['mae'].min()]
# Out:
#     camadas  epochs  neuronios ativacao  \
# 30        1     100        128     relu
#
#                                                scaler           mae  \
# 30  <class 'sklearn.preprocessing._data.StandardSc...  49866.553973
#
#             rmse      mape
# 30  72656.394161  0.664476

# %% [markdown]
# ## 2 camadas

# %%
df = pd.read_csv("mlp_2c.csv")

# %%
df.head()
# Out:
#    bi_lstm  dense      epochs neuronios  \
# 0        2     50  (256, 128)      relu
# 1        2     50  (256, 128)      relu
# 2        2     50  (256, 128)      relu
# 3        2     50  (256, 128)     swish
# 4        2     50  (256, 128)     swish
#
#                                        ativacao_lstm  ativacao_normal  \
# 0  <class 'sklearn.preprocessing._data.StandardSc...     41371.437382
# 1  <class 'sklearn.preprocessing._data.MinMaxScal...     51326.380031
# 2  <class 'sklearn.preprocessing._data.PowerTrans...     37203.376607
# 3  <class 'sklearn.preprocessing._data.StandardSc...     39187.797117
# 4  <class 'sklearn.preprocessing._data.MinMaxScal...     41822.471220
#
#    normalizacao       mae  rmse  mape
# 0  71241.877465  0.515616   NaN   NaN
# 1  85911.856023  0.616795   NaN   NaN
# 2  61874.840328  0.431909   NaN   NaN
# 3  59486.120006  0.505132   NaN   NaN
# 4  72895.405736  0.604841   NaN   NaN

# %%
df = df.drop(["rmse", "mape"], axis=1)
df.columns = ["camadas", "epochs", "neuronios", "ativacao", "scaler", "mae", "rmse","mape"]

# %%
df[df['mape'] == df['mape'].min()]
# Out:
#     camadas  epochs  neuronios ativacao  \
# 50        2     100  (256, 32)     relu
#
#                                                scaler           mae  \
# 50  <class 'sklearn.preprocessing._data.PowerTrans...  32407.028752
#
#             rmse      mape
# 50  55355.127272  0.354055

# %%
df[df['mae'] == df['mae'].min()]
# Out:
#     camadas  epochs  neuronios ativacao  \
# 87        2     150  (256, 32)    swish
#
#                                                scaler           mae  \
# 87  <class 'sklearn.preprocessing._data.StandardSc...  29763.529366
#
#             rmse      mape
# 87  44132.171825  0.420914

# %% [markdown]
# ## 3 camadas

# %%
df = pd.read_csv("mlp_3c.csv")

# %%
df.head()
# Out:
#    bi_lstm  dense          epochs neuronios  \
# 0        2     50  (256, 128, 64)      relu
# 1        2     50  (256, 128, 64)      relu
# 2        2     50  (256, 128, 64)      relu
# 3        2     50  (256, 128, 64)     swish
# 4        2     50  (256, 128, 64)     swish
#
#                                        ativacao_lstm  ativacao_normal  \
# 0  <class 'sklearn.preprocessing._data.StandardSc...     30002.439361
# 1  <class 'sklearn.preprocessing._data.MinMaxScal...     42713.278904
# 2  <class 'sklearn.preprocessing._data.PowerTrans...     32172.396971
# 3  <class 'sklearn.preprocessing._data.StandardSc...     30703.132052
# 4  <class 'sklearn.preprocessing._data.MinMaxScal...     34654.993306
#
#    normalizacao       mae  rmse  mape
# 0  48310.067298  0.470206   NaN   NaN
# 1  77553.783912  0.445415   NaN   NaN
# 2  55486.235861  0.347017   NaN   NaN
# 3  45578.514072  0.389070   NaN   NaN
# 4  59991.394406  0.474579   NaN   NaN

# %%
df = df.drop(["rmse", "mape"], axis=1)

# %%
df.columns = ["camadas", "epochs", "neuronios", "ativacao", "scaler", "mae", "rmse","mape"]

# %%
df[df['mape'] == df['mape'].min()]
# Out:
#     camadas  epochs      neuronios ativacao  \
# 39        2     100  (256, 64, 32)    swish
#
#                                                scaler           mae  \
# 39  <class 'sklearn.preprocessing._data.StandardSc...  25520.878431
#
#             rmse     mape
# 39  42929.241362  0.25177

# %%
df[df['mae'] == df['mae'].min()]
# Out:
#     camadas  epochs      neuronios ativacao  \
# 39        2     100  (256, 64, 32)    swish
#
#                                                scaler           mae  \
# 39  <class 'sklearn.preprocessing._data.StandardSc...  25520.878431
#
#             rmse     mape
# 39  42929.241362  0.25177

# %% [markdown]
# ## 4 camadas

# %%
df = pd.read_csv("mlp_4c.csv")

# %%
df.head()
# Out:
#    bi_lstm  dense              epochs neuronios  \
# 0        2     50  (256, 128, 64, 32)      relu
# 1        2     50  (256, 128, 64, 32)      relu
# 2        2     50  (256, 128, 64, 32)      relu
# 3        2     50  (256, 128, 64, 32)     swish
# 4        2     50  (256, 128, 64, 32)     swish
#
#                                        ativacao_lstm  ativacao_normal  \
# 0  <class 'sklearn.preprocessing._data.StandardSc...     26326.160748
# 1  <class 'sklearn.preprocessing._data.MinMaxScal...     34343.872179
# 2  <class 'sklearn.preprocessing._data.PowerTrans...     31532.772866
# 3  <class 'sklearn.preprocessing._data.StandardSc...     36856.448015
# 4  <class 'sklearn.preprocessing._data.MinMaxScal...     30476.705090
#
#    normalizacao       mae  rmse  mape
# 0  41438.217823  0.364909   NaN   NaN
# 1  63744.230626  0.349668   NaN   NaN
# 2  52116.961893  0.324656   NaN   NaN
# 3  55762.412489  0.393365   NaN   NaN
# 4  51480.998679  0.411971   NaN   NaN

# %%
df = df.drop(["rmse", "mape"], axis=1)

# %%
df.columns = ["camadas", "epochs", "neuronios", "ativacao", "scaler", "mae", "rmse","mape"]

# %%
df[df['mape'] == df['mape'].min()]
# Out:
#     camadas  epochs           neuronios ativacao  \
# 16        2     150  (256, 128, 64, 32)    swish
#
#                                                scaler          mae  \
# 16  <class 'sklearn.preprocessing._data.MinMaxScal...  24458.88427
#
#             rmse      mape
# 16  38424.874399  0.300042

# %%
df[df['mae'] == df['mae'].min()]
# Out:
#     camadas  epochs           neuronios ativacao  \
# 16        2     150  (256, 128, 64, 32)    swish
#
#                                                scaler          mae  \
# 16  <class 'sklearn.preprocessing._data.MinMaxScal...  24458.88427
#
#             rmse      mape
# 16  38424.874399  0.300042

# %% [markdown]
# # LSTM

# %% [markdown]
# # 1 camada

# %%
df = pd.read_csv("1_camada_lstm.csv")

# %%
df.head()
# Out:
#    lstm  dense  epochs  neuronios ativacao_lstm  ativacao_normal  \
# 0     1      0      50        256          tanh              NaN
# 1     1      0      50        256          tanh              NaN
# 2     1      0      50        256          tanh              NaN
# 3     1      0      50        256          tanh              NaN
# 4     1      0      50        256          tanh              NaN
#
#                                         normalizacao            mae  \
# 0  <class 'sklearn.preprocessing._data.StandardSc...  145620.711233
# 1  <class 'sklearn.preprocessing._data.StandardSc...  145675.618287
# 2  <class 'sklearn.preprocessing._data.MinMaxScal...  145615.780219
# 3  <class 'sklearn.preprocessing._data.MinMaxScal...  145680.838155
# 4  <class 'sklearn.preprocessing._data.PowerTrans...  145620.523386
#
#             rmse      mape
# 0  230701.962303  0.956742
# 1  230904.269365  0.956121
# 2  230703.060559  0.956318
# 3  230907.645260  0.956238
# ...

# %%
df[df['mape'] == df['mape'].min()]
# Out:
#      lstm  dense  epochs  neuronios ativacao_lstm  ativacao_normal  \
# 204     1      0     150         32          relu              NaN
#
#                                           normalizacao           mae  \
# 204  <class 'sklearn.preprocessing._data.StandardSc...  22694.215808
#
#              rmse      mape
# 204  43918.041892  0.189037

# %%
df[df['mae'] == df['mae'].min()]
# Out:
#     lstm  dense  epochs  neuronios ativacao_lstm  ativacao_normal  \
# 42     1      0      50         64          relu              NaN
#
#                                          normalizacao           mae  \
# 42  <class 'sklearn.preprocessing._data.StandardSc...  21920.128251
#
#             rmse      mape
# 42  35788.082371  0.230807

# %% [markdown]
# # 2 camadas

# %%
df = pd.read_csv("2_camada_lstm.csv")

# %%
df.head()
# Out:
#    lstm  dense  epochs   neuronios ativacao_lstm  ativacao_normal  \
# 0     2      0      50  (256, 128)          tanh              NaN
# 1     2      0      50  (256, 128)          tanh              NaN
# 2     2      0      50  (256, 128)          tanh              NaN
# 3     2      0      50  (256, 128)          tanh              NaN
# 4     2      0      50  (256, 128)          tanh              NaN
#
#                                         normalizacao  timesteps  \
# 0  <class 'sklearn.preprocessing._data.StandardSc...          3
# 1  <class 'sklearn.preprocessing._data.StandardSc...          5
# 2  <class 'sklearn.preprocessing._data.MinMaxScal...          3
# 3  <class 'sklearn.preprocessing._data.MinMaxScal...          5
# 4  <class 'sklearn.preprocessing._data.PowerTrans...          3
#
#              mae           rmse      mape
# 0  146535.603309  231284.738465  0.977992
# 1  146606.448246  231492.731599  0.978083
# 2  146537.989216  231286.250160  0.978048
# ...

# %%
df[df['mape'] == df['mape'].min()]
# Out:
#      lstm  dense  epochs   neuronios ativacao_lstm  ativacao_normal  \
# 229     2      0     150  (256, 128)         swish              NaN
#
#                                           normalizacao  timesteps  \
# 229  <class 'sklearn.preprocessing._data.StandardSc...          5
#
#               mae          rmse      mape
# 229  25002.061556  47565.155206  0.194949

# %%
df[df['mae'] == df['mae'].min()]
# Out:
#      lstm  dense  epochs   neuronios ativacao_lstm  ativacao_normal  \
# 231     2      0     150  (256, 128)         swish              NaN
#
#                                           normalizacao  timesteps  \
# 231  <class 'sklearn.preprocessing._data.MinMaxScal...          5
#
#               mae          rmse     mape
# 231  22157.857039  41223.864247  0.20139

# %%
df = pd.read_csv("lstm_2c.csv")

# %%
df.head()
# Out:
#    gru  dense  epochs neuronios ativacao_gru  ativacao_normal  \
# 0    2      0     150  (64, 32)         tanh              NaN
# 1    2      0     150  (64, 32)         tanh              NaN
# 2    2      0     150  (64, 32)         tanh              NaN
# 3    2      0     150  (64, 32)         tanh              NaN
# 4    2      0     150  (64, 32)         tanh              NaN
#
#                                         normalizacao  timesteps  \
# 0  <class 'sklearn.preprocessing._data.StandardSc...          3
# 1  <class 'sklearn.preprocessing._data.StandardSc...          5
# 2  <class 'sklearn.preprocessing._data.MinMaxScal...          3
# 3  <class 'sklearn.preprocessing._data.MinMaxScal...          5
# 4  <class 'sklearn.preprocessing._data.PowerTrans...          3
#
#              mae           rmse      mape
# 0  146758.589130  231426.080452  0.983246
# 1  146821.743253  231629.139848  0.983164
# 2  146759.636921  231426.744908  0.983270
# ...

# %%
df[df['mape'] == df['mape'].min()]
# Out:
#     gru  dense  epochs  neuronios ativacao_gru  ativacao_normal  \
# 51    2      0     150  (128, 64)        swish              NaN
#
#                                          normalizacao  timesteps  \
# 51  <class 'sklearn.preprocessing._data.MinMaxScal...          5
#
#              mae          rmse      mape
# 51  26763.250349  55239.973041  0.218563

# %%
df[df['mae'] == df['mae'].min()]
# Out:
#     gru  dense  epochs  neuronios ativacao_gru  ativacao_normal  \
# 69    2      0     150  (256, 32)        swish              NaN
#
#                                          normalizacao  timesteps  \
# 69  <class 'sklearn.preprocessing._data.MinMaxScal...          5
#
#              mae          rmse      mape
# 69  22440.350515  40414.132892  0.230471

# %% [markdown]
# # GRU

# %% [markdown]
# ## 1 camada

# %%
df = pd.read_csv("gru_1c.csv")

# %%
df.head()
# Out:
#    gru  dense  epochs  neuronios ativacao_gru  ativacao_normal  \
# 0    1      0     100        128         tanh              NaN
# 1    1      0     100        128         tanh              NaN
# 2    1      0     100        128         tanh              NaN
# 3    1      0     100        128         tanh              NaN
# 4    1      0     100        128         tanh              NaN
#
#                                         normalizacao  timesteps  \
# 0  <class 'sklearn.preprocessing._data.StandardSc...          3
# 1  <class 'sklearn.preprocessing._data.StandardSc...          5
# 2  <class 'sklearn.preprocessing._data.MinMaxScal...          3
# 3  <class 'sklearn.preprocessing._data.MinMaxScal...          5
# 4  <class 'sklearn.preprocessing._data.PowerTrans...          3
#
#              mae           rmse      mape
# 0  145610.034504  230699.435149  0.956182
# 1  145679.347199  230906.704828  0.956203
# 2  145615.453693  230702.855604  0.956310
# ...

# %%
df[df['mape'] == df['mape'].min()]
# Out:
#     gru  dense  epochs  neuronios ativacao_gru  ativacao_normal  \
# 69    1      0     150        128        swish              NaN
#
#                                          normalizacao  timesteps  \
# 69  <class 'sklearn.preprocessing._data.MinMaxScal...          5
#
#              mae          rmse      mape
# 69  29343.047004  66767.873153  0.245196

# %%
df[df['mae'] == df['mae'].min()]
# Out:
#     gru  dense  epochs  neuronios ativacao_gru  ativacao_normal  \
# 30    1      0     100         64        swish              NaN
#
#                                          normalizacao  timesteps  \
# 30  <class 'sklearn.preprocessing._data.StandardSc...          3
#
#              mae          rmse      mape
# 30  21752.504851  33752.908425  0.261156

# %%
df = pd.read_csv("gru_1c_b.csv")

# %%
df.head()
# Out:
#    gru  dense  epochs  neuronios ativacao_gru  ativacao_normal  \
# 0    1      0     150        256         tanh              NaN
# 1    1      0     150        256         tanh              NaN
# 2    1      0     150        256         tanh              NaN
# 3    1      0     150        256         tanh              NaN
# 4    1      0     150        256         tanh              NaN
#
#                                         normalizacao  timesteps  \
# 0  <class 'sklearn.preprocessing._data.StandardSc...          3
# 1  <class 'sklearn.preprocessing._data.StandardSc...          5
# 2  <class 'sklearn.preprocessing._data.MinMaxScal...          3
# 3  <class 'sklearn.preprocessing._data.MinMaxScal...          5
# 4  <class 'sklearn.preprocessing._data.PowerTrans...          3
#
#              mae           rmse      mape
# 0  141966.990761  228412.474542  0.872843
# 1  142039.425970  228622.659079  0.872801
# 2  141975.684731  228417.904291  0.873037
# ...

# %%
df[df['mape'] == df['mape'].min()]
# Out:
#     gru  dense  epochs  neuronios ativacao_gru  ativacao_normal  \
# 15    1      0     150        256        swish              NaN
#
#                                          normalizacao  timesteps  \
# 15  <class 'sklearn.preprocessing._data.MinMaxScal...          5
#
#              mae          rmse      mape
# 15  26750.987571  52281.184412  0.244416

# %%
df[df['mae'] == df['mae'].min()]
# Out:
#     gru  dense  epochs  neuronios ativacao_gru  ativacao_normal  \
# 15    1      0     150        256        swish              NaN
#
#                                          normalizacao  timesteps  \
# 15  <class 'sklearn.preprocessing._data.MinMaxScal...          5
#
#              mae          rmse      mape
# 15  26750.987571  52281.184412  0.244416

# %% [markdown]
# ## 2 camadas

# %%
df = pd.read_csv("gru_2c.csv")

# %%
df.head()
# Out:
#    gru  dense  epochs   neuronios ativacao_gru  ativacao_normal  \
# 0    2      0      50  (256, 128)         tanh              NaN
# 1    2      0      50  (256, 128)         tanh              NaN
# 2    2      0      50  (256, 128)         tanh              NaN
# 3    2      0      50  (256, 128)         tanh              NaN
# 4    2      0      50  (256, 128)         tanh              NaN
#
#                                         normalizacao  timesteps  \
# 0  <class 'sklearn.preprocessing._data.StandardSc...          3
# 1  <class 'sklearn.preprocessing._data.StandardSc...          5
# 2  <class 'sklearn.preprocessing._data.MinMaxScal...          3
# 3  <class 'sklearn.preprocessing._data.MinMaxScal...          5
# 4  <class 'sklearn.preprocessing._data.PowerTrans...          3
#
#              mae           rmse      mape
# 0  146532.824055  231282.977660  0.977926
# 1  146599.372223  231488.250393  0.977916
# 2  146535.074421  231284.403420  0.977979
# ...

# %%
df[df['mape'] == df['mape'].min()]
# Out:
#      gru  dense  epochs  neuronios ativacao_gru  ativacao_normal  \
# 267    2      0     150  (256, 32)        swish              NaN
#
#                                           normalizacao  timesteps  \
# 267  <class 'sklearn.preprocessing._data.MinMaxScal...          5
#
#               mae          rmse      mape
# 267  24991.856829  50601.765913  0.200679

# %%
df[df['mae'] == df['mae'].min()]
# Out:
#      gru  dense  epochs neuronios ativacao_gru  ativacao_normal  \
# 102    2      0      50  (64, 32)        swish              NaN
#
#                                           normalizacao  timesteps  \
# 102  <class 'sklearn.preprocessing._data.StandardSc...          3
#
#              mae         rmse      mape
# 102  22321.80551  35788.28879  0.278496

# %% [markdown]
# # Bidirectional

# %% [markdown]
# ## GRU

# %% [markdown]
# ### 2 camada

# %%
df = pd.read_csv("bi_2c_gru.csv")

# %%
df.head()
# Out:
#    gru  dense  epochs   neuronios ativacao_gru  ativacao_normal  \
# 0    2      0     100  (256, 128)         tanh              NaN
# 1    2      0     100  (256, 128)         tanh              NaN
# 2    2      0     100  (256, 128)         tanh              NaN
# 3    2      0     100  (256, 128)         tanh              NaN
# 4    2      0     100  (256, 128)         tanh              NaN
#
#                                         normalizacao  timesteps  \
# 0  <class 'sklearn.preprocessing._data.StandardSc...          3
# 1  <class 'sklearn.preprocessing._data.StandardSc...          5
# 2  <class 'sklearn.preprocessing._data.MinMaxScal...          3
# 3  <class 'sklearn.preprocessing._data.MinMaxScal...          5
# 4  <class 'sklearn.preprocessing._data.PowerTrans...          3
#
#              mae           rmse      mape
# 0  143792.768322  229555.399341  0.914093
# 1  143859.642480  229761.624107  0.913991
# 2  143797.018735  229558.068240  0.914190
# ...

# %%
df[df['mape'] == df['mape'].min()]
# Out:
#     gru  dense  epochs neuronios ativacao_gru  ativacao_normal  \
# 97    2      0     100  (64, 32)         relu              NaN
#
#                                          normalizacao  timesteps  \
# 97  <class 'sklearn.preprocessing._data.StandardSc...          5
#
#              mae          rmse      mape
# 97  20979.679291  34916.595943  0.202067

# %%
df[df['mae'] == df['mae'].min()]
# Out:
#     gru  dense  epochs  neuronios ativacao_gru  ativacao_normal  \
# 86    2      0     100  (128, 32)        swish              NaN
#
#                                          normalizacao  timesteps  \
# 86  <class 'sklearn.preprocessing._data.MinMaxScal...          3
#
#              mae          rmse      mape
# 86  19445.077824  30473.984802  0.223504

# %%
df = pd.read_csv("bi_2c_gru_50.csv")

# %%
df.head()
# Out:
#    gru  dense  epochs   neuronios ativacao_gru  ativacao_normal  \
# 0    2      0      50  (256, 128)         tanh              NaN
# 1    2      0      50  (256, 128)         tanh              NaN
# 2    2      0      50  (256, 128)         tanh              NaN
# 3    2      0      50  (256, 128)         tanh              NaN
# 4    2      0      50  (256, 128)         tanh              NaN
#
#                                         normalizacao  timesteps  \
# 0  <class 'sklearn.preprocessing._data.StandardSc...          3
# 1  <class 'sklearn.preprocessing._data.StandardSc...          5
# 2  <class 'sklearn.preprocessing._data.MinMaxScal...          3
# 3  <class 'sklearn.preprocessing._data.MinMaxScal...          5
# 4  <class 'sklearn.preprocessing._data.PowerTrans...          3
#
#              mae           rmse      mape
# 0  145613.583825  230701.675379  0.956266
# 1  145680.490631  230907.426222  0.956230
# 2  145617.980671  230704.450595  0.956369
# ...

# %%
df[df['mape'] == df['mape'].min()]
# Out:
#     gru  dense  epochs   neuronios ativacao_gru  ativacao_normal  \
# 11    2      0      50  (256, 128)         relu              NaN
#
#                                          normalizacao  timesteps  \
# 11  <class 'sklearn.preprocessing._data.PowerTrans...          5
#
#              mae          rmse      mape
# 11  20992.537895  35816.538065  0.201074

# %%
df[df['mae'] == df['mae'].min()]
# Out:
#     gru  dense  epochs   neuronios ativacao_gru  ativacao_normal  \
# 11    2      0      50  (256, 128)         relu              NaN
#
#                                          normalizacao  timesteps  \
# 11  <class 'sklearn.preprocessing._data.PowerTrans...          5
#
#              mae          rmse      mape
# 11  20992.537895  35816.538065  0.201074

# %%
df = pd.read_csv("bi_2c_gru_150.csv")

# %%
df.head()
# Out:
#    gru  dense  epochs   neuronios ativacao_gru  ativacao_normal  \
# 0    2      0     150  (256, 128)         tanh              NaN
# 1    2      0     150  (256, 128)         tanh              NaN
# 2    2      0     150  (256, 128)         tanh              NaN
# 3    2      0     150  (256, 128)         tanh              NaN
# 4    2      0     150  (256, 128)         tanh              NaN
#
#                                         normalizacao  timesteps  \
# 0  <class 'sklearn.preprocessing._data.StandardSc...          3
# 1  <class 'sklearn.preprocessing._data.StandardSc...          5
# 2  <class 'sklearn.preprocessing._data.MinMaxScal...          3
# 3  <class 'sklearn.preprocessing._data.MinMaxScal...          5
# 4  <class 'sklearn.preprocessing._data.PowerTrans...          3
#
#              mae           rmse      mape
# 0  141976.129342  228418.181975  0.873047
# 1  142042.877375  228624.813745  0.872878
# 2  141980.367969  228420.829254  0.873142
# ...

# %%
df[df['mape'] == df['mape'].min()]
# Out:
#     gru  dense  epochs  neuronios ativacao_gru  ativacao_normal  \
# 87    2      0     150  (128, 32)        swish              NaN
#
#                                          normalizacao  timesteps  \
# 87  <class 'sklearn.preprocessing._data.MinMaxScal...          5
#
#              mae          rmse      mape
# 87  20883.449011  36594.077879  0.200743

# %%
df[df['mae'] == df['mae'].min()]
# Out:
#     gru  dense  epochs  neuronios ativacao_gru  ativacao_normal  \
# 87    2      0     150  (128, 32)        swish              NaN
#
#                                          normalizacao  timesteps  \
# 87  <class 'sklearn.preprocessing._data.MinMaxScal...          5
#
#              mae          rmse      mape
# 87  20883.449011  36594.077879  0.200743

# %% [markdown]
# ## LSTM

# %% [markdown]
# ### 1 camada

# %%
df = pd.read_csv("bi_lstm_1c.csv")

# %%
df.head()
# Out:
#    bi_lstm  dense  epochs  neuronios ativacao_lstm  ativacao_normal  \
# 0        1      0      50        256          tanh              NaN
# 1        1      0      50        256          tanh              NaN
# 2        1      0      50        256          tanh              NaN
# 3        1      0      50        256          tanh              NaN
# 4        1      0      50        256          tanh              NaN
#
#                                         normalizacao            mae  \
# 0  <class 'sklearn.preprocessing._data.StandardSc...  143800.326110
# 1  <class 'sklearn.preprocessing._data.StandardSc...  143845.726225
# 2  <class 'sklearn.preprocessing._data.MinMaxScal...  143792.126001
# 3  <class 'sklearn.preprocessing._data.MinMaxScal...  143855.390686
# 4  <class 'sklearn.preprocessing._data.PowerTrans...  143804.931273
#
#             rmse      mape
# 0  229551.167659  0.914928
# 1  229752.689283  0.913692
# 2  229554.991565  0.914079
# 3  229758.953647  0.913894
# ...

# %%
df[df['mape'] == df['mape'].min()]
# Out:
#      bi_lstm  dense  epochs  neuronios ativacao_lstm  ativacao_normal  \
# 207        1      0     150         32          relu              NaN
#
#                                           normalizacao           mae  \
# 207  <class 'sklearn.preprocessing._data.MinMaxScal...  19184.841707
#
#             rmse      mape
# 207  33942.03968  0.173411

# %%
df[df['mae'] == df['mae'].min()]
# Out:
#      bi_lstm  dense  epochs  neuronios ativacao_lstm  ativacao_normal  \
# 207        1      0     150         32          relu              NaN
#
#                                           normalizacao           mae  \
# 207  <class 'sklearn.preprocessing._data.MinMaxScal...  19184.841707
#
#             rmse      mape
# 207  33942.03968  0.173411

# %% [markdown]
# ### 2 camadas

# %%
df = pd.read_csv("bi_2c_lstm.csv")

# %%
df.head()
# Out:
#    gru  dense  epochs   neuronios ativacao_gru  ativacao_normal  \
# 0    2      0      50  (256, 128)         tanh              NaN
# 1    2      0      50  (256, 128)         tanh              NaN
# 2    2      0      50  (256, 128)         tanh              NaN
# 3    2      0      50  (256, 128)         tanh              NaN
# 4    2      0      50  (256, 128)         tanh              NaN
#
#                                         normalizacao  timesteps  \
# 0  <class 'sklearn.preprocessing._data.StandardSc...          3
# 1  <class 'sklearn.preprocessing._data.StandardSc...          5
# 2  <class 'sklearn.preprocessing._data.MinMaxScal...          3
# 3  <class 'sklearn.preprocessing._data.MinMaxScal...          5
# 4  <class 'sklearn.preprocessing._data.PowerTrans...          3
#
#              mae           rmse      mape
# 0  145620.891071  230706.287617  0.956438
# 1  145680.155150  230907.214571  0.956222
# 2  145624.992267  230708.876298  0.956535
# ...

# %%
df[df['mape'] == df['mape'].min()]
# Out:
#      gru  dense  epochs  neuronios ativacao_gru  ativacao_normal  \
# 141    2      0     100  (256, 64)        swish              NaN
#
#                                           normalizacao  timesteps  \
# 141  <class 'sklearn.preprocessing._data.MinMaxScal...          5
#
#               mae          rmse     mape
# 141  21598.847529  38171.794156  0.21287

# %%
df[df['mae'] == df['mae'].min()]
# Out:
#     gru  dense  epochs  neuronios ativacao_gru  ativacao_normal  \
# 68    2      0      50  (128, 64)        swish              NaN
#
#                                          normalizacao  timesteps  \
# 68  <class 'sklearn.preprocessing._data.MinMaxScal...          3
#
#              mae         rmse      mape
# 68  20668.289513  32847.05664  0.220403

# %%
df = pd.read_csv("bi_2c_lstm_150.csv")

# %%
df.head()
# Out:
#    gru  dense  epochs   neuronios ativacao_gru  ativacao_normal  \
# 0    2      0     150  (256, 128)         tanh              NaN
# 1    2      0     150  (256, 128)         tanh              NaN
# 2    2      0     150  (256, 128)         tanh              NaN
# 3    2      0     150  (256, 128)         tanh              NaN
# 4    2      0     150  (256, 128)         tanh              NaN
#
#                                         normalizacao  timesteps  \
# 0  <class 'sklearn.preprocessing._data.StandardSc...          3
# 1  <class 'sklearn.preprocessing._data.StandardSc...          5
# 2  <class 'sklearn.preprocessing._data.MinMaxScal...          3
# 3  <class 'sklearn.preprocessing._data.MinMaxScal...          5
# 4  <class 'sklearn.preprocessing._data.PowerTrans...          3
#
#              mae           rmse      mape
# 0  142000.643695  228433.493350  0.873594
# 1  142042.498366  228624.577133  0.872870
# 2  142004.721484  228436.040447  0.873685
# ...

# %%
df[df['mape'] == df['mape'].min()]
# Out:
#     gru  dense  epochs neuronios ativacao_gru  ativacao_normal  \
# 99    2      0     150  (64, 32)         relu              NaN
#
#                                          normalizacao  timesteps  \
# 99  <class 'sklearn.preprocessing._data.MinMaxScal...          5
#
#              mae          rmse      mape
# 99  22963.653186  38688.186579  0.201691

# %%
df[df['mae'] == df['mae'].min()]
# Out:
#      bi_lstm  dense  epochs  neuronios ativacao_lstm  ativacao_normal  \
# 207        1      0     150         32          relu              NaN
#
#                                           normalizacao           mae  \
# 207  <class 'sklearn.preprocessing._data.MinMaxScal...  19184.841707
#
#             rmse      mape
# 207  33942.03968  0.173411
